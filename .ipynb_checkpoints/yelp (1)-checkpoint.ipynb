# %%
/FileStore/tables/positive_words_txt.txt
File uploaded to /FileStore/tables/negative_words_txt.txt

# %%
import pandas as pd

# %%
import pyspark

# %%
########Predicting food poisoning with Yelp data#####################


from pyspark.sql.functions import *
from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType

from pyspark.mllib.classification import SVMModel, SVMWithSGD
from pyspark.mllib.regression import LabeledPoint
from pyspark.mllib.linalg import Vectors as MLLibVectors
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.feature import * 
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder


from nltk.stem.porter import *
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

import pandas as pd
import string 
import re

# %%
sparkDF1 = spark.read.csv("/FileStore/tables/negative_words_txt.txt")

# %%
sparkDF = spark.read.csv("/FileStore/tables/positive_words_txt.txt")

# %%
positive_list=(sparkDF.select('_c0').rdd.flatMap(lambda x: x).collect())

# %%
positive_list
# Out:
# Out[37]: ['abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'acclamation',
#  'accolade',
#  'accolades',
#  'accommodative',
#  'accomodative',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'achievible',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'admiringly',
#  'adorable',
#  'adore',
#  'adored',
#  'adorer',
#  'adoring',
#  'adoringly',
#  'adroit',
#  'adroitly',
#  'adulate',
#  'adulation',
#  'adulatory',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affability',
#  'affable',
#  'affably',
#  'affectation',
#  'affection',
#  'affectionate',
#  'affinity',
#  'affirm',
#  'affirmation',
#  'affirmative',
#  'affluence',
#  'affluent',
#  'afford',
#  'affordable',
#  'affordably',
#  'afordable',
#  'agile',
#  'agilely',
#  'agility',
#  'agreeable',
#  'agreeableness',
#  'agreeably',
#  'all-around',
#  'alluring',
#  'alluringly',
#  'altruistic',
#  'altruistically',
#  'amaze',
#  'amazed',
#  'amazement',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'ambitious',
#  'ambitiously',
#  'ameliorate',
#  'amenable',
#  'amenity',
#  'amiability',
#  'amiabily',
#  'amiable',
#  'amicability',
#  'amicable',
#  'amicably',
#  'amity',
#  'ample',
#  'amply',
#  'amuse',
#  'amusing',
#  'amusingly',
#  'angel',
#  'angelic',
#  'apotheosis',
#  'appeal',
#  'appealing',
#  'applaud',
#  'appreciable',
#  'appreciate',
#  'appreciated',
#  'appreciates',
#  'appreciative',
#  'appreciatively',
#  'appropriate',
#  'approval',
#  'approve',
#  'ardent',
#  'ardently',
#  'ardor',
#  'articulate',
#  'aspiration',
#  'aspirations',
#  'aspire',
#  'assurance',
#  'assurances',
#  'assure',
#  'assuredly',
#  'assuring',
#  'astonish',
#  'astonished',
#  'astonishing',
#  'astonishingly',
#  'astonishment',
#  'astound',
#  'astounded',
#  'astounding',
#  'astoundingly',
#  'astutely',
#  'attentive',
#  'attraction',
#  'attractive',
#  'attractively',
#  'attune',
#  'audible',
#  'audibly',
#  'auspicious',
#  'authentic',
#  'authoritative',
#  'autonomous',
#  'available',
#  'aver',
#  'avid',
#  'avidly',
#  'award',
#  'awarded',
#  'awards',
#  'awe',
#  'awed',
#  'awesome',
#  'awesomely',
#  'awesomeness',
#  'awestruck',
#  'awsome',
#  'backbone',
#  'balanced',
#  'bargain',
#  'beauteous',
#  'beautiful',
#  'beautifullly',
#  'beautifully',
#  'beautify',
#  'beauty',
#  'beckon',
#  'beckoned',
#  'beckoning',
#  'beckons',
#  'believable',
#  'believeable',
#  'beloved',
#  'benefactor',
#  'beneficent',
#  'beneficial',
#  'beneficially',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'benevolence',
#  'benevolent',
#  'benifits',
#  'best',
#  'best-known',
#  'best-performing',
#  'best-selling',
#  'better',
#  'better-known',
#  'better-than-expected',
#  'beutifully',
#  'blameless',
#  'bless',
#  'blessing',
#  'bliss',
#  'blissful',
#  'blissfully',
#  'blithe',
#  'blockbuster',
#  'bloom',
#  'blossom',
#  'bolster',
#  'bonny',
#  'bonus',
#  'bonuses',
#  'boom',
#  'booming',
#  'boost',
#  'boundless',
#  'bountiful',
#  'brainiest',
#  'brainy',
#  'brand-new',
#  'brave',
#  'bravery',
#  'bravo',
#  'breakthrough',
#  'breakthroughs',
#  'breathlessness',
#  'breathtaking',
#  'breathtakingly',
#  'breeze',
#  'bright',
#  'brighten',
#  'brighter',
#  'brightest',
#  'brilliance',
#  'brilliances',
#  'brilliant',
#  'brilliantly',
#  'brisk',
#  'brotherly',
#  'bullish',
#  'buoyant',
#  'cajole',
#  'calm',
#  'calming',
#  'calmness',
#  'capability',
#  'capable',
#  'capably',
#  'captivate',
#  'captivating',
#  'carefree',
#  'cashback',
#  'cashbacks',
#  'catchy',
#  'celebrate',
#  'celebrated',
#  'celebration',
#  'celebratory',
#  'champ',
#  'champion',
#  'charisma',
#  'charismatic',
#  'charitable',
#  'charm',
#  'charming',
#  'charmingly',
#  'chaste',
#  'cheaper',
#  'cheapest',
#  'cheer',
#  'cheerful',
#  'cheery',
#  'cherish',
#  'cherished',
#  'cherub',
#  'chic',
#  'chivalrous',
#  'chivalry',
#  'civility',
#  'civilize',
#  'clarity',
#  'classic',
#  'classy',
#  'clean',
#  'cleaner',
#  'cleanest',
#  'cleanliness',
#  'cleanly',
#  'clear',
#  'clear-cut',
#  'cleared',
#  'clearer',
#  'clearly',
#  'clears',
#  'clever',
#  'cleverly',
#  'cohere',
#  'coherence',
#  'coherent',
#  'cohesive',
#  'colorful',
#  'comely',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comforting',
#  'comfy',
#  'commend',
#  'commendable',
#  'commendably',
#  'commitment',
#  'commodious',
#  'compact',
#  'compactly',
#  'compassion',
#  'compassionate',
#  'compatible',
#  'competitive',
#  'complement',
#  'complementary',
#  'complemented',
#  'complements',
#  'compliant',
#  'compliment',
#  'complimentary',
#  'comprehensive',
#  'conciliate',
#  'conciliatory',
#  'concise',
#  'confidence',
#  'confident',
#  'congenial',
#  'congratulate',
#  'congratulation',
#  'congratulations',
#  'congratulatory',
#  'conscientious',
#  'considerate',
#  'consistent',
#  'consistently',
#  'constructive',
#  'consummate',
#  'contentment',
#  'continuity',
#  'contrasty',
#  'contribution',
#  'convenience',
#  'convenient',
#  'conveniently',
#  'convience',
#  'convienient',
#  'convient',
#  'convincing',
#  'convincingly',
#  'cool',
#  'coolest',
#  'cooperative',
#  'cooperatively',
#  'cornerstone',
#  'correct',
#  'correctly',
#  'cost-effective',
#  'cost-saving',
#  'counter-attack',
#  'counter-attacks',
#  'courage',
#  'courageous',
#  'courageously',
#  'courageousness',
#  'courteous',
#  'courtly',
#  'covenant',
#  'cozy',
#  'creative',
#  'credence',
#  'credible',
#  'crisp',
#  'crisper',
#  'cure',
#  'cure-all',
#  'cushy',
#  'cute',
#  'cuteness',
#  'danke',
#  'danken',
#  'daring',
#  'daringly',
#  'darling',
#  'dashing',
#  'dauntless',
#  'dawn',
#  'dazzle',
#  'dazzled',
#  'dazzling',
#  'dead-cheap',
#  'dead-on',
#  'decency',
#  'decent',
#  'decisive',
#  'decisiveness',
#  'dedicated',
#  'defeat',
#  'defeated',
#  'defeating',
#  'defeats',
#  'defender',
#  'deference',
#  'deft',
#  'deginified',
#  'delectable',
#  'delicacy',
#  'delicate',
#  'delicious',
#  'delight',
#  'delighted',
#  'delightful',
#  'delightfully',
#  'delightfulness',
#  'dependable',
#  'dependably',
#  'deservedly',
#  'deserving',
#  'desirable',
#  'desiring',
#  'desirous',
#  'destiny',
#  'detachable',
#  'devout',
#  'dexterous',
#  'dexterously',
#  'dextrous',
#  'dignified',
#  'dignify',
#  'dignity',
#  'diligence',
#  'diligent',
#  'diligently',
#  'diplomatic',
#  'dirt-cheap',
#  'distinction',
#  'distinctive',
#  'distinguished',
#  'diversified',
#  'divine',
#  'divinely',
#  'dominate',
#  'dominated',
#  'dominates',
#  'dote',
#  'dotingly',
#  'doubtless',
#  'dreamland',
#  'dumbfounded',
#  'dumbfounding',
#  'dummy-proof',
#  'durable',
#  'dynamic',
#  'eager',
#  'eagerly',
#  'eagerness',
#  'earnest',
#  'earnestly',
#  'earnestness',
#  'ease',
#  'eased',
#  'eases',
#  'easier',
#  'easiest',
#  'easiness',
#  'easing',
#  'easy',
#  'easy-to-use',
#  'easygoing',
#  'ebullience',
#  'ebullient',
#  'ebulliently',
#  'ecenomical',
#  'economical',
#  'ecstasies',
#  'ecstasy',
#  'ecstatic',
#  'ecstatically',
#  'edify',
#  'educated',
#  'effective',
#  'effectively',
#  'effectiveness',
#  'effectual',
#  'efficacious',
#  'efficient',
#  'efficiently',
#  'effortless',
#  'effortlessly',
#  'effusion',
#  'effusive',
#  'effusively',
#  'effusiveness',
#  'elan',
#  'elate',
#  'elated',
#  'elatedly',
#  'elation',
#  'electrify',
#  'elegance',
#  'elegant',
#  'elegantly',
#  'elevate',
#  'elite',
#  'eloquence',
#  'eloquent',
#  'eloquently',
#  'embolden',
#  'eminence',
#  'eminent',
#  'empathize',
#  'empathy',
#  'empower',
#  'empowerment',
#  'enchant',
#  'enchanted',
#  'enchanting',
#  'enchantingly',
#  'encourage',
#  'encouragement',
#  'encouraging',
#  'encouragingly',
#  'endear',
#  'endearing',
#  'endorse',
#  'endorsed',
#  'endorsement',
#  'endorses',
#  'endorsing',
#  'energetic',
#  'energize',
#  'energy-efficient',
#  'energy-saving',
#  'engaging',
#  'engrossing',
#  'enhance',
#  'enhanced',
#  'enhancement',
#  'enhances',
#  'enjoy',
#  'enjoyable',
#  'enjoyably',
#  'enjoyed',
#  'enjoying',
#  'enjoyment',
#  'enjoys',
#  'enlighten',
#  'enlightenment',
#  'enliven',
#  'ennoble',
#  'enough',
#  'enrapt',
#  'enrapture',
#  'enraptured',
#  'enrich',
#  'enrichment',
#  'enterprising',
#  'entertain',
#  'entertaining',
#  'entertains',
#  'enthral',
#  'enthrall',
#  'enthralled',
#  'enthuse',
#  'enthusiasm',
#  'enthusiast',
#  'enthusiastic',
#  'enthusiastically',
#  'entice',
#  'enticed',
#  'enticing',
#  'enticingly',
#  'entranced',
#  'entrancing',
#  'entrust',
#  'enviable',
#  'enviably',
#  'envious',
#  'enviously',
#  'enviousness',
#  'envy',
#  'equitable',
#  'ergonomical',
#  'err-free',
#  'erudite',
#  'ethical',
#  'eulogize',
#  'euphoria',
#  'euphoric',
#  'euphorically',
#  'evaluative',
#  'evenly',
#  'eventful',
#  'everlasting',
#  'evocative',
#  'exalt',
#  'exaltation',
#  'exalted',
#  'exaltedly',
#  'exalting',
#  'exaltingly',
#  'examplar',
#  'examplary',
#  'excallent',
#  'exceed',
#  'exceeded',
#  'exceeding',
#  'exceedingly',
#  'exceeds',
#  'excel',
#  'exceled',
#  'excelent',
#  'excellant',
#  'excelled',
#  'excellence',
#  'excellency',
#  'excellent',
#  'excellently',
#  'excels',
#  'exceptional',
#  'exceptionally',
#  'excite',
#  'excited',
#  'excitedly',
#  'excitedness',
#  'excitement',
#  'excites',
#  'exciting',
#  'excitingly',
#  'exellent',
#  'exemplar',
#  'exemplary',
#  'exhilarate',
#  'exhilarating',
#  'exhilaratingly',
#  'exhilaration',
#  'exonerate',
#  'expansive',
#  'expeditiously',
#  'expertly',
#  'exquisite',
#  'exquisitely',
#  'extol',
#  'extoll',
#  'extraordinarily',
#  'extraordinary',
#  'exuberance',
#  'exuberant',
#  'exuberantly',
#  'exult',
#  'exultant',
#  'exultation',
#  'exultingly',
#  'eye-catch',
#  'eye-catching',
#  'eyecatch',
#  'eyecatching',
#  'fabulous',
#  'fabulously',
#  'facilitate',
#  'fair',
#  'fairly',
#  'fairness',
#  'faith',
#  'faithful',
#  'faithfully',
#  'faithfulness',
#  'fame',
#  'famed',
#  'famous',
#  'famously',
#  'fancier',
#  'fancinating',
#  'fancy',
#  'fanfare',
#  'fans',
#  'fantastic',
#  'fantastically',
#  'fascinate',
#  'fascinating',
#  'fascinatingly',
#  'fascination',
#  'fashionable',
#  'fashionably',
#  'fast',
#  'fast-growing',
#  'fast-paced',
#  'faster',
#  'fastest',
#  'fastest-growing',
#  'faultless',
#  'fav',
#  'fave',
#  'favor',
#  'favorable',
#  'favored',
#  'favorite',
#  'favorited',
#  'favour',
#  'fearless',
#  'fearlessly',
#  'feasible',
#  'feasibly',
#  'feat',
#  'feature-rich',
#  'fecilitous',
#  'feisty',
#  'felicitate',
#  'felicitous',
#  'felicity',
#  'fertile',
#  'fervent',
#  'fervently',
#  'fervid',
#  'fervidly',
#  'fervor',
#  'festive',
#  'fidelity',
#  'fiery',
#  'fine',
#  'fine-looking',
#  'finely',
#  'finer',
#  'finest',
#  'firmer',
#  'first-class',
#  'first-in-class',
#  'first-rate',
#  'flashy',
#  'flatter',
#  'flattering',
#  'flatteringly',
#  'flawless',
#  'flawlessly',
#  'flexibility',
#  'flexible',
#  'flourish',
#  'flourishing',
#  'fluent',
#  'flutter',
#  'fond',
#  'fondly',
#  'fondness',
#  'foolproof',
#  'foremost',
#  'foresight',
#  'formidable',
#  'fortitude',
#  'fortuitous',
#  'fortuitously',
#  'fortunate',
#  'fortunately',
#  'fortune',
#  'fragrant',
#  'free',
#  'freed',
#  'freedom',
#  'freedoms',
#  'fresh',
#  'fresher',
#  'freshest',
#  'friendliness',
#  'friendly',
#  'frolic',
#  'frugal',
#  'fruitful',
#  'ftw',
#  'fulfillment',
#  'fun',
#  'futurestic',
#  'futuristic',
#  'gaiety',
#  'gaily',
#  'gain',
#  'gained',
#  'gainful',
#  'gainfully',
#  'gaining',
#  'gains',
#  'gallant',
#  'gallantly',
#  'galore',
#  'geekier',
#  'geeky',
#  'gem',
#  'gems',
#  'generosity',
#  'generous',
#  'generously',
#  'genial',
#  'genius',
#  'gentle',
#  'gentlest',
#  'genuine',
#  'gifted',
#  'glad',
#  'gladden',
#  'gladly',
#  'gladness',
#  'glamorous',
#  'glee',
#  'gleeful',
#  'gleefully',
#  'glimmer',
#  'glimmering',
#  'glisten',
#  'glistening',
#  'glitter',
#  'glitz',
#  'glorify',
#  'glorious',
#  'gloriously',
#  'glory',
#  'glow',
#  'glowing',
#  'glowingly',
#  'god-given',
#  'god-send',
#  'godlike',
#  'godsend',
#  'gold',
#  'golden',
#  'good',
#  'goodly',
#  'goodness',
#  'goodwill',
#  'goood',
#  'gooood',
#  'gorgeous',
#  'gorgeously',
#  'grace',
#  'graceful',
#  'gracefully',
#  'gracious',
#  'graciously',
#  'graciousness',
#  'grand',
#  'grandeur',
#  'grateful',
#  'gratefully',
#  'gratification',
#  'gratified',
#  'gratifies',
#  'gratify',
#  'gratifying',
#  'gratifyingly',
#  'gratitude',
#  'great',
#  'greatest',
#  'greatness',
#  'grin',
#  'groundbreaking',
#  'guarantee',
#  'guidance',
#  'guiltless',
#  'gumption',
#  'gush',
#  'gusto',
#  'gutsy',
#  'hail',
#  'halcyon',
#  'hale',
#  'hallmark',
#  'hallmarks',
#  'hallowed',
#  'handier',
#  'handily',
#  'hands-down',
#  'handsome',
#  'handsomely',
#  'handy',
#  'happier',
#  'happily',
#  'happiness',
#  'happy',
#  'hard-working',
#  'hardier',
#  'hardy',
#  'harmless',
#  'harmonious',
#  'harmoniously',
#  'harmonize',
#  'harmony',
#  'headway',
#  'heal',
#  'healthful',
#  'healthy',
#  'hearten',
#  'heartening',
#  'heartfelt',
#  'heartily',
#  'heartwarming',
#  'heaven',
#  'heavenly',
#  'helped',
#  'helpful',
#  'helping',
#  'hero',
#  'heroic',
#  'heroically',
#  'heroine',
#  'heroize',
#  'heros',
#  'high-quality',
#  'high-spirited',
#  'hilarious',
#  'holy',
#  'homage',
#  'honest',
#  'honesty',
#  'honor',
#  'honorable',
#  'honored',
#  'honoring',
#  'hooray',
#  'hopeful',
#  'hospitable',
#  'hot',
#  'hotcake',
#  'hotcakes',
#  'hottest',
#  'hug',
#  'humane',
#  'humble',
#  'humility',
#  'humor',
#  'humorous',
#  'humorously',
#  'humour',
#  'humourous',
#  'ideal',
#  'idealize',
#  'ideally',
#  'idol',
#  'idolize',
#  'idolized',
#  'idyllic',
#  'illuminate',
#  'illuminati',
#  'illuminating',
#  'illumine',
#  'illustrious',
#  'ilu',
#  'imaculate',
#  'imaginative',
#  'immaculate',
#  'immaculately',
#  'immense',
#  'impartial',
#  'impartiality',
#  'impartially',
#  'impassioned',
#  'impeccable',
#  'impeccably',
#  'important',
#  'impress',
#  'impressed',
#  'impresses',
#  'impressive',
#  'impressively',
#  'impressiveness',
#  'improve',
#  'improved',
#  'improvement',
#  'improvements',
#  'improves',
#  'improving',
#  'incredible',
#  'incredibly',
#  'indebted',
#  'individualized',
#  'indulgence',
#  'indulgent',
#  'industrious',
#  'inestimable',
#  'inestimably',
#  'inexpensive',
#  'infallibility',
#  'infallible',
#  'infallibly',
#  'influential',
#  'ingenious',
#  'ingeniously',
#  'ingenuity',
#  'ingenuous',
#  'ingenuously',
#  'innocuous',
#  'innovation',
#  'innovative',
#  'inpressed',
#  'insightful',
#  'insightfully',
#  ...]

# %%
negative_list=(sparkDF1.select('_c0').rdd.flatMap(lambda x: x).collect())

# %%
negative_list
# Out:
# Out[40]: ['abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
#  'adulteration',
#  'adulterier',
#  'adversarial',
#  'adversary',
#  'adverse',
#  'adversity',
#  'afflict',
#  'affliction',
#  'afflictive',
#  'affront',
#  'afraid',
#  'aggravate',
#  'aggravating',
#  'aggravation',
#  'aggression',
#  'aggressive',
#  'aggressiveness',
#  'aggressor',
#  'aggrieve',
#  'aggrieved',
#  'aggrivation',
#  'aghast',
#  'agonies',
#  'agonize',
#  'agonizing',
#  'agonizingly',
#  'agony',
#  'aground',
#  'ail',
#  'ailing',
#  'ailment',
#  'aimless',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alarmingly',
#  'alienate',
#  'alienated',
#  'alienation',
#  'allegation',
#  'allegations',
#  'allege',
#  'allergic',
#  'allergies',
#  'allergy',
#  'aloof',
#  'altercation',
#  'ambiguity',
#  'ambiguous',
#  'ambivalence',
#  'ambivalent',
#  'ambush',
#  'amiss',
#  'amputate',
#  'anarchism',
#  'anarchist',
#  'anarchistic',
#  'anarchy',
#  'anemic',
#  'anger',
#  'angrily',
#  'angriness',
#  'angry',
#  'anguish',
#  'animosity',
#  'annihilate',
#  'annihilation',
#  'annoy',
#  'annoyance',
#  'annoyances',
#  'annoyed',
#  'annoying',
#  'annoyingly',
#  'annoys',
#  'anomalous',
#  'anomaly',
#  'antagonism',
#  'antagonist',
#  'antagonistic',
#  'antagonize',
#  'anti-',
#  'anti-american',
#  'anti-israeli',
#  'anti-occupation',
#  'anti-proliferation',
#  'anti-semites',
#  'anti-social',
#  'anti-us',
#  'anti-white',
#  'antipathy',
#  'antiquated',
#  'antithetical',
#  'anxieties',
#  'anxiety',
#  'anxious',
#  'anxiously',
#  'anxiousness',
#  'apathetic',
#  'apathetically',
#  'apathy',
#  'apocalypse',
#  'apocalyptic',
#  'apologist',
#  'apologists',
#  'appal',
#  'appall',
#  'appalled',
#  'appalling',
#  'appallingly',
#  'apprehension',
#  'apprehensions',
#  'apprehensive',
#  'apprehensively',
#  'arbitrary',
#  'arcane',
#  'archaic',
#  'arduous',
#  'arduously',
#  'argumentative',
#  'arrogance',
#  'arrogant',
#  'arrogantly',
#  'ashamed',
#  'asinine',
#  'asininely',
#  'asinininity',
#  'askance',
#  'asperse',
#  'aspersion',
#  'aspersions',
#  'assail',
#  'assassin',
#  'assassinate',
#  'assault',
#  'assult',
#  'astray',
#  'asunder',
#  'atrocious',
#  'atrocities',
#  'atrocity',
#  'atrophy',
#  'attack',
#  'attacks',
#  'audacious',
#  'audaciously',
#  'audaciousness',
#  'audacity',
#  'audiciously',
#  'austere',
#  'authoritarian',
#  'autocrat',
#  'autocratic',
#  'avalanche',
#  'avarice',
#  'avaricious',
#  'avariciously',
#  'avenge',
#  'averse',
#  'aversion',
#  'aweful',
#  'awful',
#  'awfully',
#  'awfulness',
#  'awkward',
#  'awkwardness',
#  'ax',
#  'babble',
#  'back-logged',
#  'back-wood',
#  'back-woods',
#  'backache',
#  'backaches',
#  'backaching',
#  'backbite',
#  'backbiting',
#  'backward',
#  'backwardness',
#  'backwood',
#  'backwoods',
#  'bad',
#  'badly',
#  'baffle',
#  'baffled',
#  'bafflement',
#  'baffling',
#  'bait',
#  'balk',
#  'banal',
#  'banalize',
#  'bane',
#  'banish',
#  'banishment',
#  'bankrupt',
#  'barbarian',
#  'barbaric',
#  'barbarically',
#  'barbarity',
#  'barbarous',
#  'barbarously',
#  'barren',
#  'baseless',
#  'bash',
#  'bashed',
#  'bashful',
#  'bashing',
#  'bastard',
#  'bastards',
#  'battered',
#  'battering',
#  'batty',
#  'bearish',
#  'beastly',
#  'bedlam',
#  'bedlamite',
#  'befoul',
#  'beg',
#  'beggar',
#  'beggarly',
#  'begging',
#  'beguile',
#  'belabor',
#  'belated',
#  'beleaguer',
#  'belie',
#  'belittle',
#  'belittled',
#  'belittling',
#  'bellicose',
#  'belligerence',
#  'belligerent',
#  'belligerently',
#  'bemoan',
#  'bemoaning',
#  'bemused',
#  'bent',
#  'berate',
#  'bereave',
#  'bereavement',
#  'bereft',
#  'berserk',
#  'beseech',
#  'beset',
#  'besiege',
#  'besmirch',
#  'bestial',
#  'betray',
#  'betrayal',
#  'betrayals',
#  'betrayer',
#  'betraying',
#  'betrays',
#  'bewail',
#  'beware',
#  'bewilder',
#  'bewildered',
#  'bewildering',
#  'bewilderingly',
#  'bewilderment',
#  'bewitch',
#  'bias',
#  'biased',
#  'biases',
#  'bicker',
#  'bickering',
#  'bid-rigging',
#  'bigotries',
#  'bigotry',
#  'bitch',
#  'bitchy',
#  'biting',
#  'bitingly',
#  'bitter',
#  'bitterly',
#  'bitterness',
#  'bizarre',
#  'blab',
#  'blabber',
#  'blackmail',
#  'blah',
#  'blame',
#  'blameworthy',
#  'bland',
#  'blandish',
#  'blaspheme',
#  'blasphemous',
#  'blasphemy',
#  'blasted',
#  'blatant',
#  'blatantly',
#  'blather',
#  'bleak',
#  'bleakly',
#  'bleakness',
#  'bleed',
#  'bleeding',
#  'bleeds',
#  'blemish',
#  'blind',
#  'blinding',
#  'blindingly',
#  'blindside',
#  'blister',
#  'blistering',
#  'bloated',
#  'blockage',
#  'blockhead',
#  'bloodshed',
#  'bloodthirsty',
#  'bloody',
#  'blotchy',
#  'blow',
#  'blunder',
#  'blundering',
#  'blunders',
#  'blunt',
#  'blur',
#  'bluring',
#  'blurred',
#  'blurring',
#  'blurry',
#  'blurs',
#  'blurt',
#  'boastful',
#  'boggle',
#  'bogus',
#  'boil',
#  'boiling',
#  'boisterous',
#  'bomb',
#  'bombard',
#  'bombardment',
#  'bombastic',
#  'bondage',
#  'bonkers',
#  'bore',
#  'bored',
#  'boredom',
#  'bores',
#  'boring',
#  'botch',
#  'bother',
#  'bothered',
#  'bothering',
#  'bothers',
#  'bothersome',
#  'bowdlerize',
#  'boycott',
#  'braggart',
#  'bragger',
#  'brainless',
#  'brainwash',
#  'brash',
#  'brashly',
#  'brashness',
#  'brat',
#  'bravado',
#  'brazen',
#  'brazenly',
#  'brazenness',
#  'breach',
#  'break',
#  'break-up',
#  'break-ups',
#  'breakdown',
#  'breaking',
#  'breaks',
#  'breakup',
#  'breakups',
#  'bribery',
#  'brimstone',
#  'bristle',
#  'brittle',
#  'broke',
#  'broken',
#  'broken-hearted',
#  'brood',
#  'browbeat',
#  'bruise',
#  'bruised',
#  'bruises',
#  'bruising',
#  'brusque',
#  'brutal',
#  'brutalising',
#  'brutalities',
#  'brutality',
#  'brutalize',
#  'brutalizing',
#  'brutally',
#  'brute',
#  'brutish',
#  'bs',
#  'buckle',
#  'bug',
#  'bugging',
#  'buggy',
#  'bugs',
#  'bulkier',
#  'bulkiness',
#  'bulky',
#  'bulkyness',
#  'bull****',
#  'bull----',
#  'bullies',
#  'bullshit',
#  'bullshyt',
#  'bully',
#  'bullying',
#  'bullyingly',
#  'bum',
#  'bump',
#  'bumped',
#  'bumping',
#  'bumpping',
#  'bumps',
#  'bumpy',
#  'bungle',
#  'bungler',
#  'bungling',
#  'bunk',
#  'burden',
#  'burdensome',
#  'burdensomely',
#  'burn',
#  'burned',
#  'burning',
#  'burns',
#  'bust',
#  'busts',
#  'busybody',
#  'butcher',
#  'butchery',
#  'buzzing',
#  'byzantine',
#  'cackle',
#  'calamities',
#  'calamitous',
#  'calamitously',
#  'calamity',
#  'callous',
#  'calumniate',
#  'calumniation',
#  'calumnies',
#  'calumnious',
#  'calumniously',
#  'calumny',
#  'cancer',
#  'cancerous',
#  'cannibal',
#  'cannibalize',
#  'capitulate',
#  'capricious',
#  'capriciously',
#  'capriciousness',
#  'capsize',
#  'careless',
#  'carelessness',
#  'caricature',
#  'carnage',
#  'carp',
#  'cartoonish',
#  'cash-strapped',
#  'castigate',
#  'castrated',
#  'casualty',
#  'cataclysm',
#  'cataclysmal',
#  'cataclysmic',
#  'cataclysmically',
#  'catastrophe',
#  'catastrophes',
#  'catastrophic',
#  'catastrophically',
#  'catastrophies',
#  'caustic',
#  'caustically',
#  'cautionary',
#  'cave',
#  'censure',
#  'chafe',
#  'chaff',
#  'chagrin',
#  'challenging',
#  'chaos',
#  'chaotic',
#  'chasten',
#  'chastise',
#  'chastisement',
#  'chatter',
#  'chatterbox',
#  'cheap',
#  'cheapen',
#  'cheaply',
#  'cheat',
#  'cheated',
#  'cheater',
#  'cheating',
#  'cheats',
#  'checkered',
#  'cheerless',
#  'cheesy',
#  'chide',
#  'childish',
#  'chill',
#  'chilly',
#  'chintzy',
#  'choke',
#  'choleric',
#  'choppy',
#  'chore',
#  'chronic',
#  'chunky',
#  'clamor',
#  'clamorous',
#  'clash',
#  'cliche',
#  'cliched',
#  'clique',
#  'clog',
#  'clogged',
#  'clogs',
#  'cloud',
#  'clouding',
#  'cloudy',
#  'clueless',
#  'clumsy',
#  'clunky',
#  'coarse',
#  'cocky',
#  'coerce',
#  'coercion',
#  'coercive',
#  'cold',
#  'coldly',
#  'collapse',
#  'collude',
#  'collusion',
#  'combative',
#  'combust',
#  'comical',
#  'commiserate',
#  'commonplace',
#  'commotion',
#  'commotions',
#  'complacent',
#  'complain',
#  'complained',
#  'complaining',
#  'complains',
#  'complaint',
#  'complaints',
#  'complex',
#  'complicated',
#  'complication',
#  'complicit',
#  'compulsion',
#  'compulsive',
#  'concede',
#  'conceded',
#  'conceit',
#  'conceited',
#  'concen',
#  'concens',
#  'concern',
#  'concerned',
#  'concerns',
#  'concession',
#  'concessions',
#  'condemn',
#  'condemnable',
#  'condemnation',
#  'condemned',
#  'condemns',
#  'condescend',
#  'condescending',
#  'condescendingly',
#  'condescension',
#  'confess',
#  'confession',
#  'confessions',
#  'confined',
#  'conflict',
#  'conflicted',
#  'conflicting',
#  'conflicts',
#  'confound',
#  'confounded',
#  'confounding',
#  'confront',
#  'confrontation',
#  'confrontational',
#  'confuse',
#  'confused',
#  'confuses',
#  'confusing',
#  'confusion',
#  'confusions',
#  'congested',
#  'congestion',
#  'cons',
#  'conscons',
#  'conservative',
#  'conspicuous',
#  'conspicuously',
#  'conspiracies',
#  'conspiracy',
#  'conspirator',
#  'conspiratorial',
#  'conspire',
#  'consternation',
#  'contagious',
#  'contaminate',
#  'contaminated',
#  'contaminates',
#  'contaminating',
#  'contamination',
#  'contempt',
#  'contemptible',
#  'contemptuous',
#  'contemptuously',
#  'contend',
#  'contention',
#  'contentious',
#  'contort',
#  'contortions',
#  'contradict',
#  'contradiction',
#  'contradictory',
#  'contrariness',
#  'contravene',
#  'contrive',
#  'contrived',
#  'controversial',
#  'controversy',
#  'convoluted',
#  'corrode',
#  'corrosion',
#  'corrosions',
#  'corrosive',
#  'corrupt',
#  'corrupted',
#  'corrupting',
#  'corruption',
#  'corrupts',
#  'corruptted',
#  'costlier',
#  'costly',
#  'counter-productive',
#  'counterproductive',
#  'coupists',
#  'covetous',
#  'coward',
#  'cowardly',
#  'crabby',
#  'crack',
#  'cracked',
#  'cracks',
#  'craftily',
#  'craftly',
#  'crafty',
#  'cramp',
#  'cramped',
#  'cramping',
#  'cranky',
#  'crap',
#  'crappy',
#  'craps',
#  'crash',
#  'crashed',
#  'crashes',
#  'crashing',
#  'crass',
#  'craven',
#  'cravenly',
#  'craze',
#  'crazily',
#  'craziness',
#  'crazy',
#  'creak',
#  'creaking',
#  'creaks',
#  'credulous',
#  'creep',
#  'creeping',
#  'creeps',
#  'creepy',
#  'crept',
#  'crime',
#  'criminal',
#  'cringe',
#  'cringed',
#  'cringes',
#  'cripple',
#  'crippled',
#  'cripples',
#  'crippling',
#  'crisis',
#  'critic',
#  'critical',
#  'criticism',
#  'criticisms',
#  'criticize',
#  'criticized',
#  'criticizing',
#  'critics',
#  'cronyism',
#  'crook',
#  'crooked',
#  'crooks',
#  'crowded',
#  'crowdedness',
#  'crude',
#  'cruel',
#  'crueler',
#  'cruelest',
#  'cruelly',
#  'cruelness',
#  'cruelties',
#  'cruelty',
#  'crumble',
#  'crumbling',
#  'crummy',
#  'crumple',
#  'crumpled',
#  'crumples',
#  'crush',
#  'crushed',
#  'crushing',
#  'cry',
#  'culpable',
#  'culprit',
#  'cumbersome',
#  'cunt',
#  'cunts',
#  'cuplrit',
#  'curse',
#  'cursed',
#  'curses',
#  'curt',
#  'cuss',
#  'cussed',
#  'cutthroat',
#  'cynical',
#  'cynicism',
#  'd*mn',
#  'damage',
#  'damaged',
#  'damages',
#  'damaging',
#  'damn',
#  'damnable',
#  'damnably',
#  'damnation',
#  'damned',
#  'damning',
#  'damper',
#  'danger',
#  'dangerous',
#  'dangerousness',
#  'dark',
#  'darken',
#  'darkened',
#  'darker',
#  'darkness',
#  'dastard',
#  'dastardly',
#  'daunt',
#  'daunting',
#  'dauntingly',
#  'dawdle',
#  'daze',
#  'dazed',
#  'dead',
#  'deadbeat',
#  'deadlock',
#  'deadly',
#  'deadweight',
#  'deaf',
#  'dearth',
#  'death',
#  'debacle',
#  'debase',
#  'debasement',
#  'debaser',
#  'debatable',
#  'debauch',
#  'debaucher',
#  'debauchery',
#  'debilitate',
#  'debilitating',
#  'debility',
#  'debt',
#  'debts',
#  'decadence',
#  'decadent',
#  'decay',
#  'decayed',
#  'deceit',
#  'deceitful',
#  'deceitfully',
#  'deceitfulness',
#  'deceive',
#  'deceiver',
#  'deceivers',
#  'deceiving',
#  'deception',
#  'deceptive',
#  'deceptively',
#  'declaim',
#  'decline',
#  'declines',
#  'declining',
#  'decrement',
#  'decrepit',
#  'decrepitude',
#  'decry',
#  'defamation',
#  'defamations',
#  'defamatory',
#  'defame',
#  'defect',
#  'defective',
#  'defects',
#  'defensive',
#  'defiance',
#  'defiant',
#  'defiantly',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'defile',
#  'defiler',
#  'deform',
#  'deformed',
#  'defrauding',
#  'defunct',
#  'defy',
#  'degenerate',
#  'degenerately',
#  'degeneration',
#  'degradation',
#  'degrade',
#  'degrading',
#  'degradingly',
#  'dehumanization',
#  'dehumanize',
#  'deign',
#  'deject',
#  'dejected',
#  'dejectedly',
#  'dejection',
#  'delay',
#  'delayed',
#  'delaying',
#  'delays',
#  'delinquency',
#  'delinquent',
#  'delirious',
#  'delirium',
#  'delude',
#  'deluded',
#  'deluge',
#  'delusion',
#  'delusional',
#  'delusions',
#  'demean',
#  'demeaning',
#  'demise',
#  'demolish',
#  'demolisher',
#  'demon',
#  'demonic',
#  'demonize',
#  'demonized',
#  'demonizes',
#  'demonizing',
#  'demoralize',
#  'demoralizing',
#  'demoralizingly',
#  'denial',
#  'denied',
#  'denies',
#  'denigrate',
#  'denounce',
#  'dense',
#  'dent',
#  'dented',
#  'dents',
#  'denunciate',
#  'denunciation',
#  'denunciations',
#  'deny',
#  'denying',
#  'deplete',
#  'deplorable',
#  'deplorably',
#  'deplore',
#  'deploring',
#  'deploringly',
#  'deprave',
#  'depraved',
#  'depravedly',
#  'deprecate',
#  'depress',
#  'depressed',
#  'depressing',
#  'depressingly',
#  'depression',
#  'depressions',
#  'deprive',
#  'deprived',
#  'deride',
#  'derision',
#  'derisive',
#  'derisively',
#  'derisiveness',
#  'derogatory',
#  'desecrate',
#  'desert',
#  'desertion',
#  'desiccate',
#  'desiccated',
#  'desititute',
#  'desolate',
#  'desolately',
#  'desolation',
#  'despair',
#  'despairing',
#  'despairingly',
#  'desperate',
#  'desperately',
#  'desperation',
#  'despicable',
#  'despicably',
#  'despise',
#  'despised',
#  ...]

# %%
#s3://shivaniproj/parquets/yelp_academic_dataset_review/
review = spark.read.load("s3://shivaniproj/parquets/yelp_academic_dataset_review/",format="parquet")

# %%
review.cache()
# Out:
# Out[123]: DataFrame[business_id: string, cool: bigint, date: string, funny: bigint, review_id: string, stars: double, text: string, useful: bigint, user_id: string]

# %%
review.show(2)
# Out:
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |y7Ssng5Bnl75QiZUE...|   0|2016-03-06 08:49:08|    0|lyjloY7uVRsaOZObr...|  4.0|Ever wanted too j...|     0|Vu1P84ifxzFeQ9qRF...|
# |4fzjAjzLCnjWfQP1s...|   0|2013-12-04 22:37:18|    0|GfPzojSq1cin_fOdf...|  5.0|Dry-aged bone-in ...|     0|J1n84Z7tRI8Y7nhFU...|
# +--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 2 rows

# %%
# remove punctuation
def remove_punct(text):
    regex = re.compile('[' + re.escape(string.punctuation) + '0-9\\r\\t\\n]')
    nopunct = regex.sub(" ", text) 
    return nopunct
    
# binarize rating
def convert_rating(rating):
    rating = int(rating)
    if rating <2: return 0
    else: return 1

# udf
punct_remover = udf(lambda x: remove_punct(x))
rating_convert = udf(lambda x: convert_rating(x))
review_df = review.select('review_id', punct_remover('text'), rating_convert('stars'))
review_df = review_df.withColumnRenamed('<lambda>(text)', 'text')\
                     .withColumn('label', review_df["<lambda>(stars)"].cast(IntegerType()))\
                     .drop('<lambda>(stars)')\
                     .limit(500)

# %%
review_df.show(5)
# Out:
# +--------------------+--------------------+-----+
# |           review_id|                text|label|
# +--------------------+--------------------+-----+
# |lyjloY7uVRsaOZObr...|Ever wanted too j...|    1|
# |GfPzojSq1cin_fOdf...|Dry aged bone in ...|    1|
# |lFphcMI6ZN2uFA8wg...|I lived in Boston...|    1|
# |oQDDv49nI55lHzsI3...|Some good things ...|    1|
# |78ZDs404elxc0f1i-...|Great place to gr...|    1|
# +--------------------+--------------------+-----+
# only showing top 5 rows

# %%
review_df_itr=review_df.toPandas()
texts=[]
for review in review_df_itr.text:
    texts.append(review)

# %%
texts
# Out:
# Out[91]: ['Ever wanted too just take a bite out of a fully grown hogs gut  That is what the five guys experience is about for me  The burgers are unreal and extremely good  Also they are generous with the fries that overflow into the bag  but the amount of fries used to be better  But the one thing that is distracting from the experience is all of the peanut corpses littered around the place  It is nut genocide  Makes me feel very uncomfortable ',
#  'Super good   super friendly  This was my first Austin  taco truck  experience and it turned out really good  My husband and I were just leaving a Yelp  event and it was on the way to our car    I had the beef taco and the spicy chicken taco   My husband had the beef burrito   It was really quick and the staff was really friendly   One of them chatted with us about the Yelp  event and said that she s been trying to get up to elite status    I couldn t tell the difference between the chicken or the beef but one of them had bones  maybe that one was the chicken one   Either way they were both delish   My husband s burrito was too spicy hot for him and he even nixed the salsa   hmmm     The tacos were just the right amount of spice for me   Oh and   tacos     burrito was only   bucks  can t beat that ',
#  'I am in agreement with Ashley C s review    I wanted to give Hobos a try for the longest time  I went there for the happy hour  The decor was nice  and it is actually rather spacious inside  The waiter was nice and helpful  too    The beer was good  but the happy hour food   in comparison  it doesn t match to Jake s or Henry s   I really hope that Hobos would revamp happy hour food  Keep the fries and tortilla  But add a salad  make it huge   a burger  and I am hoping their dinner plates are as good as Rachel Ray said    But overall  if you don t want to be in a crowded happy hour place  Hobos is actually a decent alternative ',
#  'The best ride in the park is the mummy IF YOU LIKE ROLLER COASTERS  A lot of the rides say that if you are this or that you can t ride  The cat in the hat is not scary and pregnant women CAN ride it in my opinion  It does not spin and will hurt anything if you are not   months pregnant  The hulk and the dragon are also awesome  I suggest booking to come in feb  march or apr     however  the ticket lines are RETARDED  We bought our tickets off site and still had to stand in line for an hour to get the vouchers  Even if you buy them online you have to stand in line to get the actual ticket  from the clerk and it takes forever  You need at least   days to get through universal and islands of adventure  If you are trying to park a camper turn at the valet ']

# %%
def tokenize(texts):
    tokenizer = nltk.RegexpTokenizer(r'\w+')

    texts_tokens = []
    for i, val in enumerate(texts):
        text_tokens = tokenizer.tokenize(val.lower())

        for i in range(len(text_tokens) - 1, -1, -1):
            if len(text_tokens[i]) < 4:
                del(text_tokens[i])

        texts_tokens.append(text_tokens)
        
    return texts_tokens

# %%
import nltk
texts_tokens = tokenize(texts)

# %%
texts_tokens
# Out:
# Out[26]: [['ever',
#   'wanted',
#   'just',
#   'take',
#   'bite',
#   'fully',
#   'grown',
#   'hogs',
#   'that',
#   'what',
#   'five',
#   'guys',
#   'experience',
#   'about',
#   'burgers',
#   'unreal',
#   'extremely',
#   'good',
#   'also',
#   'they',
#   'generous',
#   'with',
#   'fries',
#   'that',
#   'overflow',
#   'into',
#   'amount',
#   'fries',
#   'used',
#   'better',
#   'thing',
#   'that',
#   'distracting',
#   'from',
#   'experience',
#   'peanut',
#   'corpses',
#   'littered',
#   'around',
#   'place',
#   'genocide',
#   'makes',
#   'feel',
#   'very',
#   'uncomfortable'],
#  ['aged',
#   'bone',
#   'ribeye',
#   'best',
#   'steak',
#   'ever',
#   'eaten',
#   'corn',
#   'pudding',
#   'also',
#   'delicious',
#   'exceeded',
#   'expectations',
#   'loved',
#   'lobster',
#   'napoleon',
#   'wouldn',
#   'order',
#   'again',
#   'unless',
#   'were',
#   'splurging',
#   'steak',
#   'delicious',
#   'filling',
#   'that',
#   'need',
#   'appetizer',
#   'truffle',
#   'mashed',
#   'potatoes',
#   'were',
#   'delicious',
#   'they',
#   'were',
#   'also',
#   'what',
#   'expected',
#   'from',
#   'this',
#   'quality',
#   'restaurant',
#   'cheese',
#   'good',
#   'favorite',
#   'kind',
#   'tasted',
#   'like',
#   'trying',
#   'hard',
#   'personally',
#   'would',
#   'pass',
#   'cheesecake',
#   'good',
#   'spectacular',
#   'point',
#   'this',
#   'story',
#   'that',
#   'steak',
#   'good',
#   'waiter',
#   'could',
#   'slapped',
#   'mother',
#   'front',
#   'still',
#   'would',
#   'given',
#   'star',
#   'review'],
#  ['lived',
#   'boston',
#   'years',
#   'before',
#   'tipped',
#   'this',
#   'location',
#   'food',
#   'court',
#   'asian',
#   'food',
#   'lover',
#   'dream',
#   'come',
#   'true',
#   'from',
#   'stir',
#   'from',
#   'indian',
#   'food',
#   'this',
#   'place',
#   'lolicup',
#   'provides',
#   'tasty',
#   'drink',
#   'dessert',
#   'option',
#   'here',
#   'especially',
#   'good',
#   'great',
#   'udon',
#   'stir',
#   'frys',
#   'well',
#   'cash',
#   'only',
#   'there',
#   'site'],
#  ['some',
#   'good',
#   'things',
#   'about',
#   'alibi',
#   'comfortable',
#   'areas',
#   'talk',
#   'with',
#   'small',
#   'large',
#   'group',
#   'people',
#   'kind',
#   'lighting',
#   'that',
#   'makes',
#   'people',
#   'look',
#   'prettier',
#   'perfectly',
#   'pleasant',
#   'loud',
#   'music',
#   'plenty',
#   'people',
#   'crowded',
#   'decent',
#   'drinks',
#   'close',
#   'line',
#   'charles',
#   'cheap',
#   'quick',
#   'friendly',
#   'valet',
#   'parking',
#   'only',
#   'your',
#   'ticket',
#   'validated',
#   'alibi',
#   'clink',
#   'great',
#   'deal',
#   'neighborhood',
#   'where',
#   'street',
#   'parking',
#   'slim',
#   'pickings',
#   'especially',
#   'when',
#   'there',
#   'celtics',
#   'game',
#   'some',
#   'other',
#   'event',
#   'garden',
#   'some',
#   'annoying',
#   'things',
#   'long',
#   'lines',
#   'outside',
#   'freezing',
#   'cold',
#   'friday',
#   'nights',
#   'thing',
#   'place',
#   'really',
#   'capacity',
#   'doing',
#   'effect',
#   'just',
#   'obnoxious',
#   'after',
#   'waiting',
#   'least',
#   'twenty',
#   'minutes',
#   'friends',
#   'realized',
#   'that',
#   'holding',
#   'back',
#   'floods',
#   'been',
#   'strictly',
#   'necessary',
#   'they',
#   'easily',
#   'could',
#   'have',
#   'whole',
#   'line',
#   'maybe',
#   'people',
#   'without',
#   'making',
#   'place',
#   'uncomfortably',
#   'full',
#   'then',
#   'four',
#   'friends',
#   'there',
#   'after',
#   'they',
#   'arrived',
#   'around',
#   'waited',
#   'over',
#   'hour',
#   'including',
#   'about',
#   'minutes',
#   'very',
#   'front',
#   'line',
#   'finally',
#   'ended',
#   'leaving',
#   'avoid',
#   'frostbite',
#   'maybe',
#   'they',
#   'weren',
#   'wearing',
#   'enough',
#   'makeup',
#   'something',
#   'this',
#   'bouncer',
#   'really',
#   'rudely',
#   'power',
#   'trippy',
#   'about',
#   'whole',
#   'thing',
#   'general',
#   'staff',
#   'members',
#   'other',
#   'than',
#   'valets',
#   'were',
#   'great',
#   'example',
#   'clueless',
#   'cocktail',
#   'waitress',
#   'about',
#   'whom',
#   'friends',
#   'speculated',
#   'charitably',
#   'that',
#   'probably',
#   'first',
#   'would',
#   'come',
#   'back',
#   'table',
#   'after',
#   'minutes',
#   'point',
#   'someone',
#   'ordered',
#   'pinot',
#   'noir',
#   'also',
#   'given',
#   'that',
#   'martini',
#   'glass',
#   'with',
#   'olive',
#   'laden',
#   'toothpick',
#   'sticking',
#   'most',
#   'iconic',
#   'images',
#   'america',
#   'pretty',
#   'unimpressed',
#   'that',
#   'brought',
#   'over',
#   'dirty',
#   'martini',
#   'with',
#   'olives',
#   'apparently',
#   'didn',
#   'know',
#   'that',
#   'martinis',
#   'supposed',
#   'come',
#   'with',
#   'olives',
#   'jailhouse',
#   'themed',
#   'decor',
#   'kind',
#   'cool',
#   'novelty',
#   'although',
#   'would',
#   'have',
#   'preferred',
#   'mugshot',
#   'like',
#   'michael',
#   'jagger',
#   'francis',
#   'sinatra',
#   'rather',
#   'than',
#   'having',
#   'stare',
#   'paris',
#   'hilton',
#   'giant',
#   'sultry',
#   'gaze',
#   'imagine',
#   'might',
#   'decent',
#   'expensive',
#   'after',
#   'work',
#   'hangout',
#   'worked',
#   'boston',
#   'especially',
#   'which',
#   'right',
#   'next',
#   'door',
#   'given',
#   'that',
#   'probably',
#   'back'],
#  ['great',
#   'place',
#   'grab',
#   'burger',
#   'fast',
#   'service',
#   'friendly',
#   'staff',
#   'seating',
#   'available',
#   'inside',
#   'food',
#   'made',
#   'order',
#   'patience',
#   'virtue',
#   'worth',
#   'wait'],
#  ['like',
#   'walmart',
#   'sports',
#   'merchandise',
#   'prices',
#   'aren',
#   'that',
#   'great',
#   'boonies',
#   'crowded',
#   'nike',
#   'gear',
#   'that',
#   'great',
#   'some',
#   'people',
#   'obviously',
#   'like'],
#  ['food',
#   'incredible',
#   'tender',
#   'very',
#   'personable',
#   'will',
#   'definitely',
#   'going',
#   'back',
#   'there',
#   'brunch',
#   'they',
#   'incorporate',
#   'marvel',
#   'theme',
#   'into',
#   'restaurant',
#   'food',
#   'unlike',
#   'anything',
#   'have',
#   'ever',
#   'seen',
#   'terminator',
#   'sandwich',
#   'wife',
#   'storm',
#   'quesadilla',
#   'with',
#   'their',
#   'bloody',
#   'mary'],
#  ['haven',
#   'been',
#   'happy',
#   'with',
#   'restaurant',
#   'while',
#   'steak',
#   'sandwiches',
#   'steaks',
#   'chicken',
#   'breast',
#   'have',
#   'been',
#   'amazing',
#   'have',
#   'diary',
#   'problem',
#   'they',
#   'made',
#   'everything',
#   'from',
#   'scratch',
#   'staff',
#   'very',
#   'nice',
#   'truly',
#   'cared',
#   'about',
#   'zero',
#   'complains',
#   'thank'],
#  ['these',
#   'guys',
#   'helped',
#   'with',
#   'yakima',
#   'rack',
#   'everything',
#   'needed',
#   'stock',
#   'matt',
#   'helpful',
#   'gave',
#   'discount',
#   'being',
#   'nice',
#   'plus',
#   'coupon'],
#  ['great',
#   'service',
#   'wonderful',
#   'warm',
#   'ambiance',
#   'food',
#   'very',
#   'good',
#   'quick',
#   'fresh'],
#  ['wasn',
#   'expecting',
#   'much',
#   'downtown',
#   'never',
#   'been',
#   'home',
#   'restaurant',
#   'worth',
#   'writing',
#   'home',
#   'about',
#   'stopped',
#   'after',
#   'hike',
#   'gorge',
#   'really',
#   'hungry',
#   'peppered',
#   'flat',
#   'bread',
#   'appetizer',
#   'terrific',
#   'crust',
#   'perfect',
#   'combo',
#   'crispy',
#   'chewy',
#   'enough',
#   'cheese',
#   'almost',
#   'pizza',
#   'husband',
#   'chicken',
#   'parmesen',
#   'panini',
#   'spinach',
#   'salad',
#   'entree',
#   'chicken',
#   'great',
#   'food',
#   'made',
#   'with',
#   'love',
#   'gotta',
#   'back',
#   'their',
#   'pizza',
#   'homemade',
#   'soup',
#   'wine',
#   'glass',
#   'selection',
#   'slim',
#   'nice',
#   'blend',
#   'available',
#   'special',
#   'husband',
#   'very',
#   'happy',
#   'with',
#   'draught',
#   'double',
#   'lava'],
#  ['really',
#   'excited',
#   'this',
#   'place',
#   'brunch',
#   'after',
#   'looking',
#   'their',
#   'menu',
#   'arrived',
#   'sunday',
#   'were',
#   'seated',
#   'immediately',
#   'ordered',
#   'bloody',
#   'mary',
#   'forgetting',
#   'about',
#   'stupid',
#   'texas',
#   'laws',
#   'unable',
#   'report',
#   'booze',
#   'food',
#   'ordered',
#   'amazing',
#   'ordered',
#   'portobellino',
#   'benedict',
#   'absolutely',
#   'wonderful',
#   'possibly',
#   'best',
#   'breakfasts',
#   'have',
#   'experienced',
#   'austin',
#   'they',
#   'bring',
#   'croissants',
#   'strawberry',
#   'butter',
#   'begin',
#   'with',
#   'which',
#   'were',
#   'delicious',
#   'well',
#   'eating',
#   'croissant',
#   'really',
#   'filled',
#   'wasn',
#   'able',
#   'much',
#   'entree',
#   'there',
#   'were',
#   'plenty',
#   'leftovers',
#   'daughter',
#   'belgian',
#   'waffle',
#   'fresh',
#   'squeezed',
#   'orange',
#   'juice',
#   'both',
#   'were',
#   'very',
#   'good',
#   'server',
#   'very',
#   'attentive',
#   'were',
#   'restaurant',
#   'less',
#   'than',
#   'minutes',
#   'bill',
#   'five',
#   'people',
#   'close',
#   'after',
#   'little',
#   'more',
#   'expensive',
#   'than',
#   'some',
#   'other',
#   'brunch',
#   'places',
#   'definitely',
#   'worth',
#   'look',
#   'forward',
#   'going',
#   'back',
#   'chez',
#   'next',
#   'time',
#   'austin'],
#  ['delightful',
#   'dinner',
#   'come',
#   'quick',
#   'before',
#   'crowds',
#   'everything',
#   'ordered',
#   'yummy',
#   'staff',
#   'still',
#   'working',
#   'kinks',
#   'rhythm'],
#  ['good',
#   'things',
#   'come',
#   'pink',
#   'boxes',
#   'they',
#   'make',
#   'sure',
#   'least',
#   'donut',
#   'spot',
#   'every',
#   'town',
#   'visit',
#   'when',
#   'chance',
#   'voodoo',
#   'flipped',
#   'waited',
#   'outside',
#   'minutes',
#   'friday',
#   'just',
#   'step',
#   'inside',
#   'worth',
#   'this',
#   'menu',
#   'absolutely',
#   'crazy',
#   'packed',
#   'with',
#   'delicious',
#   'flavors',
#   'like',
#   'marshall',
#   'mathers',
#   'dirt',
#   'donut',
#   'cock',
#   'balls',
#   'wrong',
#   'with',
#   'whatever',
#   'choose',
#   'because',
#   'donuts',
#   'extremely',
#   'light',
#   'airy',
#   'fresh',
#   'huge',
#   'contemplating',
#   'buying',
#   'ticket',
#   'portland',
#   'just',
#   'some',
#   'more'],
#  ['well',
#   'this',
#   'place',
#   'decent',
#   'food',
#   'find',
#   'that',
#   'they',
#   'charge',
#   'extra',
#   'getting',
#   'breaded',
#   'chicken',
#   'your',
#   'salad',
#   'lady',
#   'rings',
#   'your',
#   'food',
#   'handles',
#   'money',
#   'also',
#   'uses',
#   'bare',
#   'hands',
#   'pita',
#   'bread',
#   'your',
#   'shame',
#   'back',
#   'that',
#   'reason',
#   'grossed'],
#  ['like',
#   'idea',
#   'eating',
#   'meal',
#   'movie',
#   'theatre',
#   'only',
#   'they',
#   'gouge',
#   'when',
#   'ticket',
#   'they',
#   'also',
#   'charge',
#   'high',
#   'their',
#   'food',
#   'other',
#   'than',
#   'that',
#   'like',
#   'experience',
#   'drinker',
#   'that',
#   'part',
#   'does',
#   'nothing',
#   'however',
#   'wouldn',
#   'opposed',
#   'returning',
#   'here'],
#  ['great',
#   'service',
#   'staff',
#   'that',
#   'wants',
#   'deliver',
#   'service',
#   'they',
#   'also',
#   'have',
#   'wing',
#   'called',
#   'austin',
#   'shipping',
#   'solutions',
#   'have',
#   'some',
#   'expensive',
#   'school',
#   'arcade',
#   'games',
#   'storage',
#   'their',
#   'facility',
#   'cheap',
#   'great',
#   'place',
#   'your',
#   'ball',
#   'delivery',
#   'packaging',
#   'custom',
#   'crating',
#   'needs',
#   'just',
#   'give',
#   'them',
#   'call',
#   'have',
#   'been',
#   'disappointed'],
#  ['biggest',
#   'forget',
#   'coming',
#   'mooo',
#   'during',
#   'restaurant',
#   'week',
#   'dine',
#   'boston',
#   'weeks',
#   'mooo',
#   'offers',
#   'fixe',
#   'three',
#   'course',
#   'meal',
#   'during',
#   'lunch',
#   'time',
#   'every',
#   'basis',
#   'even',
#   'better',
#   'menu',
#   'options',
#   'from',
#   'their',
#   'everyday',
#   'fixe',
#   'menu',
#   'opinion',
#   'better',
#   'than',
#   'offerings',
#   'during',
#   'restaurant',
#   'week',
#   'able',
#   'maine',
#   'lobster',
#   'bisque',
#   'cognac',
#   'drizzle',
#   'fresh',
#   'lobster',
#   'meat',
#   'hand',
#   'chopped',
#   'steak',
#   'tartare',
#   'with',
#   'grilled',
#   'flatbread',
#   'grilled',
#   'york',
#   'sirloin',
#   'roasted',
#   'garlic',
#   'marrow',
#   'butter',
#   'truffled',
#   'frites',
#   'bananas',
#   'foster',
#   'mascarpone',
#   'whipped',
#   'cream',
#   'valrhona',
#   'chocolate',
#   'cake',
#   'cardamom',
#   'crème',
#   'anglaise',
#   'cocoa',
#   'dusted',
#   'whipped',
#   'cream',
#   'lobster',
#   'bisque',
#   'favorite',
#   'appetizers',
#   'creamy',
#   'rich',
#   'good',
#   'chunks',
#   'lobster',
#   'steak',
#   'cooked',
#   'perfectly',
#   'liking',
#   'truffle',
#   'fries',
#   'were',
#   'bomb',
#   'after',
#   'eating',
#   'complementary',
#   'bread',
#   'appetizers',
#   'felt',
#   'slightly',
#   'full',
#   'midway',
#   'took',
#   'rest',
#   'steak',
#   'frites',
#   'left',
#   'plenty',
#   'room',
#   'dessert',
#   'both',
#   'desserts',
#   'were',
#   'good',
#   'none',
#   'stood',
#   'favorite',
#   'with',
#   'valrhona',
#   'chocolate',
#   'cake',
#   'definitely',
#   'glass',
#   'milk',
#   'help',
#   'wash',
#   'down',
#   'very',
#   'rich',
#   'they',
#   'give',
#   'plenty',
#   'service',
#   'here',
#   'great',
#   'ambiance',
#   'decor',
#   'even',
#   'better',
#   'from',
#   'outside',
#   'mooo',
#   'looks',
#   'from',
#   'impressive',
#   'inside',
#   'feels',
#   'upscale',
#   'definitely',
#   'fancy',
#   'left',
#   'restaurant',
#   'feeling',
#   'like',
#   'because',
#   'full',
#   'regardless',
#   'tummy',
#   'smiling',
#   'experience',
#   'pleasant'],
#  ['went',
#   'this',
#   'place',
#   'birthday',
#   'because',
#   'influenced',
#   'someone',
#   'longer',
#   'consider',
#   'friend',
#   'myself',
#   'family',
#   'waited',
#   'hour',
#   'into',
#   'this',
#   'place',
#   'absolutely',
#   'packed',
#   'capacity',
#   'really',
#   'think',
#   'fire',
#   'hazard',
#   'anyway',
#   'once',
#   'seated',
#   'service',
#   'poor',
#   'best',
#   'waitress',
#   'seemed',
#   'though',
#   'were',
#   'bother',
#   'customers',
#   'ordered',
#   'fried',
#   'shrimp',
#   'oysters',
#   'when',
#   'order',
#   'arrived',
#   'much',
#   'amazement',
#   'received',
#   'exactly',
#   'shrimp',
#   'fried',
#   'oysters',
#   'kept',
#   'looking',
#   'cameras',
#   'thinking',
#   'this',
#   'hidden',
#   'camera',
#   'joke',
#   'something',
#   'this',
#   'joke',
#   'want',
#   'poor',
#   'service',
#   'food',
#   'with',
#   'absolutely',
#   'taste',
#   'place',
#   'packed',
#   'capacity',
#   'this',
#   'place',
#   'will',
#   'never',
#   'ever',
#   'this',
#   'place',
#   'again',
#   'life'],
#  ['ordered',
#   'fish',
#   'sandwich',
#   'which',
#   'ended',
#   'being',
#   'more',
#   'bread',
#   'than',
#   'fish',
#   'tiny',
#   'piece',
#   'fish',
#   'less',
#   'than',
#   'manager',
#   'duty',
#   'short',
#   'hispanic',
#   'looking',
#   'with',
#   'braces',
#   'rude',
#   'uncompromising',
#   'horrible',
#   'service'],
#  ['there',
#   'specialists',
#   'that',
#   'amazing',
#   'offer',
#   'care',
#   'found',
#   'regular',
#   'will',
#   'cost',
#   'fortune',
#   'johnson',
#   'internal',
#   'amazing',
#   'switch',
#   'from',
#   'kearns',
#   'just',
#   'didn',
#   'feel',
#   'personal',
#   'connection',
#   'from',
#   'with',
#   'mechanical',
#   'frankly',
#   'little',
#   'tough',
#   'would',
#   'again',
#   'just',
#   'opposite',
#   'kissed',
#   'head',
#   'made',
#   'connection',
#   'with',
#   'before',
#   'even',
#   'examining',
#   'which',
#   'really',
#   'make',
#   'difference',
#   'sometimes',
#   'worried',
#   'stressed',
#   'clueless',
#   'frustrated',
#   'owners',
#   'been',
#   'going',
#   'there',
#   'years',
#   'everyone',
#   'there',
#   'generally',
#   'great',
#   'expensive',
#   'however',
#   'dread',
#   'having',
#   'come',
#   'there',
#   'mainly',
#   'know',
#   'bill',
#   'going',
#   'huge',
#   'even',
#   'minor',
#   'thing',
#   'that',
#   'bummer',
#   'aside',
#   'from',
#   'great',
#   'doctors',
#   'techs',
#   'kind',
#   'compassionate',
#   'staff',
#   'really',
#   'best',
#   'things',
#   'offer',
#   'even',
#   'upset',
#   'about',
#   'bill',
#   'understanding',
#   'leaves',
#   'much',
#   'better',
#   'impression',
#   'clients',
#   'everyone',
#   'know',
#   'already',
#   'goes',
#   'there',
#   'says',
#   'same',
#   'thing',
#   'that',
#   'treatment',
#   'costly',
#   'that',
#   'very',
#   'good',
#   'place',
#   'care'],
#  ['came',
#   'here',
#   'with',
#   'thai',
#   'friend',
#   'swore',
#   'beef',
#   'best',
#   'have',
#   'orlando',
#   'have',
#   'been',
#   'staple',
#   'places',
#   'also',
#   'chicken',
#   'fried',
#   'rice',
#   'pork',
#   'vermicelli',
#   'pork',
#   'plate',
#   'bahn',
#   'incredible',
#   'well',
#   'this',
#   'favorite',
#   'place',
#   'mills',
#   'area',
#   'staff',
#   'always',
#   'hardworking',
#   'considering',
#   'their',
#   'usually',
#   'only',
#   'waiters',
#   'waitresses',
#   'they',
#   'still',
#   'take',
#   'care',
#   'always',
#   'asking',
#   'need',
#   'anything'],
#  ['great',
#   'place',
#   'lunch',
#   'pimento',
#   'cheese',
#   'balls',
#   'server',
#   'seemed',
#   'nice',
#   'quick',
#   'with',
#   'orders',
#   'solid',
#   'place',
#   'business',
#   'lunch'],
#  ['city',
#   'full',
#   'places',
#   'with',
#   'great',
#   'lists',
#   'saraveza',
#   'stands',
#   'number',
#   'ways',
#   'food',
#   'excellent',
#   'looking',
#   'fashioned',
#   'comfort',
#   'food',
#   'come',
#   'right',
#   'place',
#   'deviled',
#   'eggs',
#   'reuben',
#   'pasties',
#   'sausage',
#   'plate',
#   'soup',
#   'excellent',
#   'service',
#   'quite',
#   'possibly',
#   'best',
#   'city',
#   'portland',
#   'often',
#   'reviled',
#   'terrible',
#   'service',
#   'slow',
#   'rude',
#   'saraveza',
#   'exact',
#   'opposite',
#   'never',
#   'felt',
#   'more',
#   'like',
#   'company',
#   'friends',
#   'another',
#   'portland',
#   'restaurant',
#   'they',
#   'genuinely',
#   'care',
#   'that',
#   'having',
#   'good',
#   'time',
#   'enjoying',
#   'your',
#   'experience',
#   'matter',
#   'whether',
#   'yourself',
#   'group',
#   'eight',
#   'decor',
#   'hilarious',
#   'just',
#   'check',
#   'love'],
#  ['this',
#   'pizza',
#   'best',
#   'thin',
#   'crust',
#   'light',
#   'sauce',
#   'served',
#   'quickly',
#   'nice',
#   'quiet',
#   'place',
#   'grab',
#   'quick',
#   'lunch',
#   'back',
#   'sire'],
#  ['always',
#   'enjoy',
#   'time',
#   'kaku',
#   'staff',
#   'always',
#   'courteous',
#   'simple',
#   'barbecue',
#   'sauce',
#   'combo',
#   'never',
#   'lets',
#   'down',
#   'somehow',
#   'always',
#   'ended',
#   'during',
#   'happy',
#   'hour',
#   'prices',
#   'great',
#   'some',
#   'personal',
#   'recommendations',
#   'addicting',
#   'cucumber',
#   'always',
#   'giggle',
#   'when',
#   'these',
#   'names',
#   'guess',
#   'they',
#   'right',
#   'after',
#   'beef',
#   'sirloin',
#   'hard',
#   'slow',
#   'grill',
#   'they',
#   'like',
#   'mini',
#   'steaks',
#   'tastes',
#   'great',
#   'when',
#   'medium',
#   'medium',
#   'rare',
#   'shabu',
#   'beef',
#   'very',
#   'thin',
#   'slice',
#   'with',
#   'right',
#   'amount',
#   'weaved',
#   'into',
#   'them',
#   'very',
#   'easy',
#   'cook',
#   'they',
#   'taste',
#   'great',
#   'with',
#   'spice',
#   'sauce',
#   'spicy',
#   'sauce',
#   'personal',
#   'among',
#   'three',
#   'sauces',
#   'they',
#   'table',
#   'mention',
#   'lady',
#   'matcha',
#   'cream',
#   'used',
#   'only',
#   'lady',
#   'boston',
#   'even',
#   'with',
#   'lady',
#   'store',
#   'newbury',
#   'kaku',
#   'offering',
#   'still',
#   'quite',
#   'deal',
#   'with',
#   'additional',
#   'scoops',
#   'cream'],
#  ['fact',
#   'they',
#   'even',
#   'star',
#   'only',
#   'because',
#   'guys',
#   'actual',
#   'moving',
#   'were',
#   'nice',
#   'they',
#   'were',
#   'minutes',
#   'late',
#   'arriving',
#   'stopped',
#   'once',
#   'house',
#   'second',
#   'time',
#   'gatorades',
#   'called',
#   'hour',
#   'special',
#   'from',
#   'groupon',
#   'which',
#   'lateness',
#   'move',
#   'possible',
#   'understood',
#   'that',
#   'requested',
#   'quote',
#   'anyway',
#   'from',
#   'south',
#   'austin',
#   'cedar',
#   'park',
#   'that',
#   'little',
#   'steep',
#   'decided',
#   'chance',
#   'losing',
#   'available',
#   'truck',
#   'paid',
#   'when',
#   'they',
#   'arrived',
#   'late',
#   'they',
#   'only',
#   'then',
#   'told',
#   'there',
#   'would',
#   'knows',
#   'what',
#   'they',
#   'move',
#   'unsealed',
#   'boxes',
#   'anything',
#   'with',
#   'lightbulb',
#   'straight',
#   'away',
#   'realize',
#   'they',
#   'unbonded',
#   'uninsured',
#   'which',
#   'should',
#   'have',
#   'realized',
#   'when',
#   'they',
#   'pulled',
#   'budget',
#   'rental',
#   'truck',
#   'which',
#   'somehow',
#   'ended',
#   'being',
#   'small',
#   'take',
#   'living',
#   'room',
#   'small',
#   'dining',
#   'bistro',
#   'bedroom',
#   'small',
#   'office',
#   'boxes',
#   'actually',
#   'ended',
#   'having',
#   'make',
#   'separate',
#   'trips',
#   'jeep',
#   'transport',
#   'items',
#   'they',
#   'would',
#   'bring',
#   'items',
#   'listed',
#   'above',
#   'abdul',
#   'actually',
#   'nerve',
#   'tell',
#   'later',
#   'that',
#   'stuff',
#   'didn',
#   'truck',
#   'then',
#   'clearly',
#   'must',
#   'have',
#   'been',
#   'lying',
#   'about',
#   'amount',
#   'furniture',
#   'actually',
#   'needed',
#   'transport',
#   'then',
#   'audacity',
#   'tell',
#   'would',
#   'happily',
#   'send',
#   'nother',
#   'truck',
#   'again',
#   'tomorrow',
#   'rest',
#   'stuff',
#   'already',
#   'just',
#   'moved',
#   'before',
#   'midnight',
#   'move',
#   'deadline',
#   'would',
#   'have',
#   'another',
#   'hour',
#   'husband',
#   'moved',
#   'upstairs',
#   'furniture',
#   'downstairs',
#   'make',
#   'move',
#   'easy',
#   'quick',
#   'movers',
#   'possible',
#   'they',
#   'ended',
#   'taking',
#   'extra',
#   'hours',
#   'even',
#   'with',
#   'helping',
#   'move',
#   'furniture',
#   'boxes',
#   'managed',
#   'place',
#   'only',
#   'very',
#   'large',
#   'heavy',
#   'armoires',
#   'needed',
#   'movers',
#   'first',
#   'place',
#   'into',
#   'wrong',
#   'rooms',
#   'have',
#   'move',
#   'after',
#   'they',
#   'left',
#   'there',
#   'corner',
#   'damage',
#   'very',
#   'expensive',
#   'coffee',
#   'table',
#   'several',
#   'broken',
#   'porcelain',
#   'items',
#   'scratches',
#   'other',
#   'miscellaneous',
#   'items',
#   'paid',
#   'this',
#   'moving',
#   'company',
#   'looking',
#   'good',
#   'price',
#   'responsible',
#   'movers',
#   'warning',
#   'buyer',
#   'beware'],
#  ['food',
#   'good',
#   'beat',
#   'prices',
#   'always',
#   'veggie',
#   'shrimp',
#   'bowl',
#   'fake',
#   'shrimp',
#   'course',
#   'comes',
#   'quickly',
#   'always',
#   'your',
#   'food',
#   'cool',
#   'down',
#   'veggie',
#   'heaven',
#   'tell',
#   'many',
#   'times',
#   'have',
#   'seen',
#   'people',
#   'burn',
#   'their',
#   'mouths',
#   'guzzle',
#   'water',
#   'taking',
#   'their',
#   'first',
#   'bite',
#   'first',
#   'time',
#   'place',
#   'itself',
#   'small',
#   'seating',
#   'close',
#   'together',
#   'used',
#   'weird',
#   'over',
#   'since',
#   'would',
#   'fast',
#   'staff',
#   'seems',
#   'never',
#   'change',
#   'years',
#   'have',
#   'been',
#   'going',
#   'there',
#   'expect',
#   'spectacular',
#   'service',
#   'typically',
#   'service',
#   'here',
#   'just',
#   'also',
#   'lady',
#   'runs',
#   'place',
#   'always',
#   'looks',
#   'pissed',
#   'never',
#   'fails',
#   'always',
#   'sitting',
#   'front',
#   'rolling',
#   'silverware',
#   'waiting',
#   'someone',
#   'park',
#   'going',
#   'restaurant',
#   'will',
#   'likes',
#   'yell',
#   'people',
#   'beforehand',
#   'entertaining',
#   'give',
#   'stars',
#   'because',
#   'food',
#   'prices',
#   'expect',
#   'here',
#   'very',
#   'simple',
#   'just',
#   'good',
#   'food',
#   'cheap'],
#  ['fish', 'tacos', 'margaritas', 'good', 'filled', 'with', 'watered', 'down'],
#  ['this',
#   'great',
#   'experience',
#   'employee',
#   'were',
#   'very',
#   'humorous',
#   'took',
#   'excellent',
#   'care',
#   'animals',
#   'park',
#   'also',
#   'offered',
#   'many',
#   'different',
#   'viewings',
#   'animals',
#   'really',
#   'think',
#   'going',
#   'until',
#   'there',
#   'definitely',
#   'early',
#   'because',
#   'there',
#   'many',
#   'things',
#   'wish',
#   'could',
#   'done',
#   'there',
#   'late'],
#  ['been',
#   'wearing',
#   'glasses',
#   'since',
#   'years',
#   'years',
#   'never',
#   'such',
#   'thorough',
#   'exam',
#   'staff',
#   'wonderful',
#   'lady',
#   'with',
#   'bright',
#   'hair',
#   'helped',
#   'pick',
#   'perfect',
#   'pair',
#   'glasses',
#   'fabulous',
#   'style',
#   'truly',
#   'kind',
#   'will',
#   'back',
#   'sure'],
#  ['jasmine',
#   'hair',
#   'although',
#   'sweet',
#   'good',
#   'hair',
#   'roots',
#   'straightened',
#   'flat',
#   'iron',
#   'used',
#   'looked',
#   'like',
#   'came',
#   'from',
#   'walmart',
#   'hair',
#   'there',
#   'body',
#   'tipped',
#   'because',
#   'took',
#   'close',
#   'closing',
#   'wouldn',
#   'return',
#   'people',
#   'gave',
#   'african',
#   'american',
#   'hair',
#   'should',
#   'here'],
#  ['loved',
#   'went',
#   'last',
#   'night',
#   'husband',
#   'birthday',
#   'everyone',
#   'happy',
#   'with',
#   'their',
#   'choices',
#   'smaller',
#   'inside',
#   'than',
#   'expected',
#   'tables',
#   'most',
#   'tables',
#   'outside',
#   'everyone',
#   'something',
#   'different',
#   'stuffed',
#   'grouper',
#   'salmon',
#   'scallops',
#   'grouper',
#   'sandwich',
#   'burger',
#   'shared',
#   'some',
#   'bites',
#   'everything',
#   'good',
#   'seemed',
#   'fresh',
#   'everything',
#   'cooked',
#   'well',
#   'delicious',
#   'service',
#   'good',
#   'beer',
#   'cheap',
#   'only',
#   'complaint',
#   'were',
#   'full',
#   'dessert',
#   'seeing',
#   'some',
#   'pass',
#   'they',
#   'looked',
#   'amazing'],
#  ['called',
#   'based',
#   'recommendations',
#   'yelp',
#   'they',
#   'came',
#   'promptly',
#   'estimate',
#   'came',
#   'about',
#   'days',
#   'later',
#   'install',
#   'door',
#   'they',
#   'showed',
#   'when',
#   'they',
#   'said',
#   'they',
#   'would',
#   'completed',
#   'work',
#   'about',
#   'hours',
#   'they',
#   'installed',
#   'door',
#   'opener',
#   'even',
#   'programmed',
#   'cars',
#   'opener',
#   'were',
#   'were',
#   'pleasant',
#   'helpful',
#   'thought',
#   'price',
#   'reasonable',
#   'would',
#   'highly',
#   'recommend',
#   'them'],
#  ['papusas',
#   'fifty',
#   'only',
#   'came',
#   'with',
#   'medium',
#   'sized',
#   'papusa',
#   'some',
#   'kind',
#   'vinegar',
#   'slaw',
#   'better',
#   'papusas',
#   'past',
#   'overall',
#   'underwhelmed',
#   'something',
#   'else',
#   'hereor',
#   'pass'],
#  ['love',
#   'this',
#   'place',
#   'food',
#   'excellent',
#   'chef',
#   'excellent',
#   'great',
#   'music',
#   'throughout',
#   'week',
#   'hands',
#   'down',
#   'best',
#   'place',
#   'watch',
#   'sunday',
#   'football',
#   'staff',
#   'also',
#   'great',
#   'bartenders',
#   'amazing',
#   'never',
#   'mess',
#   'order',
#   'fried',
#   'chicken',
#   'tots',
#   'favs'],
#  ['love',
#   'this',
#   'place',
#   'been',
#   'three',
#   'times',
#   'tried',
#   'pizzas',
#   'they',
#   'delicious',
#   'love',
#   'heat',
#   'also',
#   'unicorn',
#   'wings',
#   'super',
#   'good',
#   'this',
#   'regular',
#   'place',
#   'need',
#   'sandwich',
#   'next'],
#  ['food',
#   'here',
#   'authentic',
#   'several',
#   'dishes',
#   'amazing',
#   'that',
#   'keep',
#   'coming',
#   'back',
#   'almost',
#   'weekly',
#   'favorites',
#   'this',
#   'week',
#   'bringing',
#   'family',
#   'back'],
#  ['night',
#   'spent',
#   'here',
#   'worst',
#   'nights',
#   'life',
#   'like',
#   'sleeping',
#   'board',
#   'heating',
#   'system',
#   'beyond',
#   'pathetic',
#   'noise',
#   'level',
#   'from',
#   'across',
#   'street',
#   'unbearable',
#   'never',
#   'again',
#   'green'],
#  ['magic',
#   'bites',
#   'cater',
#   'party',
#   'process',
#   'couldn',
#   'have',
#   'been',
#   'easier',
#   'food',
#   'couldn',
#   'have',
#   'been',
#   'more',
#   'delicious',
#   'already',
#   'eating',
#   'magic',
#   'bites',
#   'times',
#   'week',
#   'they',
#   'feed',
#   'regularly',
#   'having',
#   'them',
#   'cater',
#   'gathering',
#   'brainer',
#   'highly',
#   'recommended'],
#  ['favorite',
#   'restaurant',
#   'time',
#   'high',
#   'quality',
#   'food',
#   'high',
#   'quality',
#   'atmosphere',
#   'high',
#   'quality',
#   'service',
#   'addition',
#   'persian',
#   'food',
#   'amazing',
#   'especially',
#   'when',
#   'done',
#   'right',
#   'like',
#   'they',
#   'rumi'],
#  ['best',
#   'fondue',
#   'seasonal',
#   'accompaniments',
#   'overall',
#   'service',
#   'always',
#   'satisfied',
#   'with',
#   'geniality',
#   'waiter',
#   'waitress',
#   'times',
#   'wait',
#   'uncomfortably',
#   'long',
#   'food',
#   'arrive',
#   'aren',
#   'starving',
#   'problem',
#   'recommend',
#   'snacking',
#   'delicious',
#   'bread',
#   'basket',
#   'that',
#   'includes',
#   'whole',
#   'wheat',
#   'options',
#   'boston',
#   'brown',
#   'bread',
#   'food',
#   'temple',
#   'specializes',
#   'modern',
#   'american',
#   'cuisine',
#   'that',
#   'suits',
#   'palate',
#   'traditional',
#   'american',
#   'flavors',
#   'blend',
#   'well',
#   'with',
#   'england',
#   'seasonal',
#   'influence',
#   'adding',
#   'modern',
#   'twist',
#   'fare',
#   'executive',
#   'chef',
#   'greg',
#   'boschetti',
#   'greg',
#   'previously',
#   'worked',
#   'chez',
#   'henri',
#   'french',
#   'meets',
#   'cuban',
#   'restaurant',
#   'cambridge',
#   'moved',
#   'from',
#   'sous',
#   'chef',
#   'executive',
#   'chef',
#   'temple',
#   'brunch',
#   'croque',
#   'eggs',
#   'benedict',
#   'with',
#   'artisanal',
#   'sour',
#   'dough',
#   'black',
#   'forest',
#   'swiss',
#   'cheese',
#   'smoked',
#   'paprika',
#   'hollandaise',
#   'home',
#   'fries',
#   'cowboy',
#   'omelet',
#   'with',
#   'chorizo',
#   'roasted',
#   'peppers',
#   'mushroom',
#   'vermont',
#   'cheddar',
#   'home',
#   'fries',
#   'meat',
#   'free',
#   'dinner',
#   'options',
#   'include',
#   'seasonal',
#   'vegetarian',
#   'charcuterie',
#   'board',
#   'with',
#   'vegetable',
#   'terinne',
#   'pequillo',
#   'pepper',
#   'hummus',
#   'lemon',
#   'edamame',
#   'daikon',
#   'radish',
#   'spring',
#   'roll',
#   'pickled',
#   'vegetables',
#   'warm',
#   'roasted',
#   'root',
#   'vegetable',
#   'tarragon',
#   'mustard',
#   'dressing',
#   'also',
#   'available',
#   'exquisite',
#   'fairly',
#   'priced',
#   'late',
#   'night',
#   'menu',
#   'options',
#   'including',
#   'crispy',
#   'confit',
#   'duck',
#   'wings',
#   'with',
#   'spicy',
#   'pineapple',
#   'duck',
#   'sauce',
#   'sweet',
#   'syrup',
#   'yuzu',
#   'citrus',
#   'tuna',
#   'tartar',
#   'with',
#   'spicy',
#   'cucumber',
#   'avocado',
#   'mousse',
#   'house',
#   'made',
#   'pickled',
#   'ginger',
#   'sesame',
#   'rice',
#   'crackers',
#   'rosemary',
#   'salt',
#   'pommes',
#   'frites',
#   'with',
#   'malt',
#   'vinegar',
#   'aioli',
#   'atmosphere',
#   'this',
#   'restaurant',
#   'where',
#   'seating',
#   'just',
#   'warm',
#   'comforting',
#   'rest',
#   'charming',
#   'interior',
#   'spacious',
#   'restaurant',
#   'exposed',
#   'brick',
#   'ambient',
#   'lighting',
#   'floor',
#   'ceiling',
#   'mirrors',
#   'fully',
#   'stocked',
#   'copper',
#   'wood',
#   'paneled',
#   'other',
#   'your',
#   'party',
#   'lounge',
#   'oversized',
#   'leather',
#   'booths',
#   'cozy',
#   'with',
#   'orchard',
#   'sour',
#   'lairds',
#   'applejack',
#   'lemon',
#   'simple',
#   'syrup',
#   'yellow',
#   'chartreuse',
#   'angostura',
#   'bitters',
#   'hightop',
#   'suitable',
#   'dining',
#   'drinking',
#   'venue',
#   'families',
#   'couples',
#   'friends',
#   'chummy',
#   'workers',
#   'price',
#   'temple',
#   'serves',
#   'fresh',
#   'seasonal',
#   'food',
#   'good',
#   'price',
#   'unique',
#   'appetizers',
#   'like',
#   'crispy',
#   'flash',
#   'fried',
#   'calamari',
#   'with',
#   'sweet',
#   'spicy',
#   'dipping',
#   'sauce',
#   'roomkass',
#   'double',
#   'creme',
#   'gouda',
#   'cheese',
#   'fondue',
#   'with',
#   'seasonal',
#   'accompaniments',
#   'respectively',
#   'meat',
#   'seafood',
#   'entrees',
#   'average',
#   'vegetarian',
#   'options',
#   'like',
#   'seasonal',
#   'risotto',
#   'seasonal',
#   'vegetable',
#   'plate',
#   'sandwiches',
#   'pizza',
#   'cheaper',
#   'costing',
#   'less',
#   'than',
#   'sides',
#   'cheapest',
#   'things',
#   'menu',
#   'olive',
#   'poached',
#   'fingerling',
#   'potatoes',
#   'sautéed',
#   'spinach',
#   'with',
#   'fried',
#   'garlic',
#   'chips',
#   'each',
#   'keep',
#   'mind',
#   'that',
#   'portions',
#   'satisfying',
#   'fill',
#   'brim',
#   'which',
#   'always',
#   'thing',
#   'accessibility',
#   'there',
#   'free',
#   'parking',
#   'daily',
#   'from',
#   'behind',
#   'restaurant',
#   'right',
#   'side',
#   'metered',
#   'parking',
#   'also',
#   'available',
#   'along',
#   'massachusetts',
#   'when',
#   'comes',
#   'public',
#   'transit',
#   'take',
#   'your',
#   'pick',
#   'between',
#   'harvard',
#   'square',
#   'porter',
#   'square',
#   'since',
#   'temple',
#   'rests',
#   'between',
#   'stations',
#   'recommendations',
#   'snake',
#   'river',
#   'farm',
#   'kobe',
#   'beef',
#   'sliders',
#   'artisan',
#   'brioche',
#   'caramelized',
#   'onions',
#   'smoked',
#   'tomato',
#   'aioli',
#   'roasted',
#   'beet',
#   'endive',
#   'salad',
#   'candied',
#   'pistachios',
#   'toasted',
#   'goat',
#   'cheese',
#   'crostini',
#   'horseradish',
#   'buttermilk',
#   'dressing',
#   'vegetarian',
#   'chef',
#   'tasting',
#   'prix',
#   'fixe',
#   'appetizer',
#   'entree',
#   'dessert',
#   'chef',
#   'choice',
#   'white',
#   'truffle',
#   'pizza',
#   'avocado',
#   'tear',
#   'drop',
#   'tomatoes',
#   'baby',
#   'arugula',
#   'white',
#   'truffle',
#   'aged',
#   'balsamic',
#   'seared',
#   'brussels',
#   'sprouts',
#   'olive',
#   'salt',
#   'roomkaas',
#   'double',
#   'creme',
#   'gouda',
#   'cheese',
#   'fondue',
#   'paired',
#   'with',
#   'seasonal',
#   'accompaniments',
#   'like',
#   'thick',
#   'pretezel',
#   'bites',
#   'thinly',
#   'sliced',
#   'pear',
#   'fingerling',
#   'potatoes',
#   'broccoli',
#   'fresh',
#   'brewed'],
#  ['horrible',
#   'biriyanis',
#   'feels',
#   'just',
#   'eating',
#   'masalas',
#   'time',
#   'when',
#   'onions',
#   'this',
#   'what'],
#  ['favorite',
#   'spots',
#   'margherita',
#   'pizzas',
#   'house',
#   'wine',
#   'between',
#   'place',
#   'chinar',
#   'their',
#   'original',
#   'location',
#   'counter',
#   'service',
#   'interior',
#   'spacious',
#   'they',
#   'also',
#   'have',
#   'some',
#   'tables',
#   'outdoor',
#   'dining',
#   'pizza',
#   'comes',
#   'quick',
#   'from',
#   'their',
#   'wood',
#   'fired',
#   'oven',
#   'normally',
#   'crusts',
#   'this',
#   'place',
#   'will',
#   'flavors',
#   'great',
#   'thin',
#   'crust',
#   'makes',
#   'easy',
#   'another',
#   'pizza',
#   'that',
#   'great',
#   'there',
#   'sausage',
#   'with',
#   'mama',
#   'peppers',
#   'wrong',
#   'with',
#   'overall',
#   'great',
#   'place',
#   'with',
#   'superb',
#   'service'],
#  ['love',
#   'these',
#   'ulta',
#   'shops',
#   'have',
#   'been',
#   'both',
#   'plymouth',
#   'braintree',
#   'nice',
#   'clean',
#   'organized',
#   'find',
#   'lots',
#   'beauty',
#   'products',
#   'usually',
#   'have',
#   'hard',
#   'time',
#   'finding',
#   'noticed',
#   'that',
#   'they',
#   'also',
#   'have',
#   'salon',
#   'back',
#   'gave',
#   'with',
#   'beti',
#   'very',
#   'personable',
#   'loved',
#   'have',
#   'short',
#   'hair',
#   'particular',
#   'with',
#   'cuts',
#   'styled',
#   'exactly',
#   'like',
#   'think',
#   'have',
#   'found',
#   'hairstylist'],
#  ['absolutely',
#   'love',
#   'lala',
#   'think',
#   'hands',
#   'down',
#   'favorite',
#   'austin',
#   'school',
#   'christmas',
#   'decor',
#   'totally',
#   'makes',
#   'void',
#   'things',
#   'hipster',
#   'trendy',
#   'think',
#   'that',
#   'like',
#   'much',
#   'like',
#   'drinking',
#   'your',
#   'grandparents',
#   'house',
#   'hamburgers',
#   'wouldn',
#   'think',
#   'they',
#   'probably',
#   'best',
#   'town',
#   'only',
#   'avoid',
#   'lala',
#   'weekends',
#   'incredibly',
#   'packed',
#   'tuesday',
#   'through',
#   'thursday',
#   'great',
#   'days',
#   'closed',
#   'monday',
#   'awesome',
#   'jukebox',
#   'only',
#   'thing',
#   'like',
#   'they',
#   'allow',
#   'smoking',
#   'sometimes',
#   'gets',
#   'little',
#   'intense',
#   'overwhelming',
#   'since',
#   'small',
#   'overall',
#   'magical',
#   'place'],
#  ['went',
#   'there',
#   'tonight',
#   'view',
#   'bruins',
#   'game',
#   'drink',
#   'some',
#   'beers',
#   'party',
#   'first',
#   'they',
#   'would',
#   'take',
#   'waiting',
#   'list',
#   'servers',
#   'just',
#   'picked',
#   'chose',
#   'they',
#   'wanted',
#   'their',
#   'table',
#   'terrible',
#   'operating',
#   'restaurant',
#   'then',
#   'waitress',
#   'lied',
#   'about',
#   'being',
#   'able',
#   'sell',
#   'pitchers',
#   'beer',
#   'tall',
#   'beers',
#   'meanwhile',
#   'every',
#   'table',
#   'around',
#   'them',
#   'very',
#   'smart',
#   'because',
#   'buckets',
#   'beer',
#   'more',
#   'expensive',
#   'wasn',
#   'born',
#   'yesterday',
#   'waitress',
#   'continuously',
#   'exclaimed',
#   'following',
#   'managements',
#   'orders',
#   'miraculously',
#   'soon',
#   'requested',
#   'speak',
#   'with',
#   'manager',
#   'pitchers',
#   'beer',
#   'were',
#   'available',
#   'service',
#   'absolutely',
#   'terrible',
#   'everyone',
#   'table',
#   'ended',
#   'purchasing',
#   'beers',
#   'from',
#   'beer',
#   'girl',
#   'entrance',
#   'lounge',
#   'honestly',
#   'only',
#   'good',
#   'thing',
#   'have',
#   'about',
#   'this',
#   'place',
#   'that',
#   'beer',
#   'girl',
#   'entrance',
#   'lounge',
#   'quite',
#   'pleasant',
#   'personable',
#   'constantly',
#   'smiling',
#   'working',
#   'that',
#   'money',
#   'would',
#   'have',
#   'traded',
#   'waitress',
#   'this',
#   'girl',
#   'heart',
#   'beat',
#   'star',
#   'beer',
#   'girl',
#   'only',
#   'that'],
#  ['okay',
#   'this',
#   'place',
#   'amazing',
#   'have',
#   'persian',
#   'food',
#   'from',
#   'many',
#   'places',
#   'this',
#   'place',
#   'chicken',
#   'beef',
#   'koobideh',
#   'this',
#   'world',
#   'extremely',
#   'tasty',
#   'juicy',
#   'rice',
#   'tomato',
#   'pairing',
#   'take',
#   'another',
#   'level',
#   'customer',
#   'service',
#   'notch',
#   'really',
#   'impressed',
#   'with',
#   'bread',
#   'definitely',
#   'must'],
#  ['know',
#   'they',
#   'stay',
#   'business',
#   'there',
#   'about',
#   'months',
#   'dots',
#   'only',
#   'thing',
#   'tasted',
#   'sugar',
#   'about',
#   'maybe',
#   'dots',
#   'nothing',
#   'talk',
#   'about',
#   'will',
#   'never',
#   'back',
#   'something',
#   'like',
#   'that',
#   'again'],
#  ['thankfully',
#   'this',
#   'places',
#   'chocolate',
#   'festival',
#   'list',
#   'that',
#   'open',
#   'late',
#   'common',
#   'working',
#   'folks',
#   'like',
#   'myself',
#   'advantage',
#   'winter',
#   'that',
#   'lining',
#   'half',
#   'block',
#   'down',
#   'gelato',
#   'therefore',
#   'easy',
#   'operation',
#   'establishment',
#   'clean',
#   'busy',
#   'decor',
#   'feel',
#   'lady',
#   'super',
#   'friendly',
#   'sweet',
#   'genuine',
#   'smile',
#   'face',
#   'salted',
#   'pecan',
#   'maple',
#   'syrup',
#   'gold',
#   'medal',
#   'winner',
#   'from',
#   'gelato',
#   'competition',
#   'italy',
#   'served',
#   'with',
#   'erin',
#   'ireland',
#   'banana',
#   'bread',
#   'holy',
#   'shit',
#   'heaven',
#   'first',
#   'bite',
#   'rather',
#   'immediately',
#   'with',
#   'salty',
#   'taste',
#   'with',
#   'sweet',
#   'aftertaste',
#   'awesome',
#   'sweet',
#   'savory',
#   'oral',
#   'sensation',
#   'mouth',
#   'most',
#   'addicting',
#   'chocolate',
#   'drink',
#   'nice',
#   'taste',
#   'smooth',
#   'chocolate',
#   'that',
#   'didn',
#   'compete',
#   'dominance',
#   'terms',
#   'flavor',
#   'notes',
#   'best',
#   'this',
#   'without',
#   'whip',
#   'cream',
#   'that',
#   'taste',
#   'true',
#   'drink',
#   'intended',
#   'banana',
#   'bread',
#   'extremely',
#   'greasy',
#   'fingers',
#   'shouldn',
#   'glistening',
#   'like',
#   'male',
#   'vegas',
#   'stripper',
#   'after',
#   'eating',
#   'pastry',
#   'total',
#   'cost'],
#  ['what',
#   'wonderful',
#   'company',
#   'great',
#   'initially',
#   'with',
#   'getting',
#   'quote',
#   'calling',
#   'back',
#   'prompt',
#   'manner',
#   'rented',
#   'their',
#   'brand',
#   'person',
#   'stretch',
#   'person',
#   'shuttle',
#   'wedding',
#   'this',
#   'past',
#   'weekend',
#   'person',
#   'stretch',
#   'beautiful',
#   'clean',
#   'same',
#   'with',
#   'shuttle',
#   'drivers',
#   'were',
#   'very',
#   'nice',
#   'were',
#   'very',
#   'accomodating',
#   'they',
#   'arrived',
#   'time',
#   'before',
#   'issues',
#   'probably',
#   'working',
#   'with',
#   'other',
#   'limo',
#   'company',
#   'good',
#   'guys',
#   'thanks',
#   'much'],
#  ['peruvian',
#   'born',
#   'raised',
#   'since',
#   'moving',
#   'have',
#   'difficulty',
#   'finding',
#   'quality',
#   'peruvian',
#   'food',
#   'that',
#   'reminds',
#   'home',
#   'llama',
#   'first',
#   'place',
#   'that',
#   'given',
#   'authentic',
#   'tasting',
#   'peruvian',
#   'food',
#   'that',
#   'keeps',
#   'coming',
#   'back',
#   'more',
#   'living',
#   'houston',
#   'have',
#   'tried',
#   'likes',
#   'lemon',
#   'tree',
#   'pollo',
#   'bravo',
#   'latin',
#   'bites',
#   'other',
#   'restaurants',
#   'that',
#   'from',
#   'time',
#   'time',
#   'disappear',
#   'within',
#   'year',
#   'nothing',
#   'compares',
#   'genuine',
#   'homecooked',
#   'taste',
#   'from',
#   'llama',
#   'food',
#   'truck',
#   'travel',
#   'austin',
#   'find',
#   'will',
#   'keep',
#   'coming',
#   'back',
#   'just',
#   'this',
#   'food',
#   'combination',
#   'flavors',
#   'intricately',
#   'expertly',
#   'together',
#   'noob',
#   'peruvian',
#   'food',
#   'highly',
#   'recommend',
#   'starting',
#   'with',
#   'pork',
#   'sandwich',
#   'juiciest',
#   'tenderest',
#   'pork',
#   'considering',
#   'hate',
#   'pork',
#   'every',
#   'other',
#   'occasion',
#   'amazing',
#   'that',
#   'this',
#   'sandwich',
#   'enough',
#   'turn',
#   'taste',
#   'buds',
#   'next',
#   'favorites',
#   'cannot',
#   'wrong',
#   'with',
#   'these',
#   'employees',
#   'always',
#   'kind',
#   'pleasant',
#   'have',
#   'anything',
#   'menu',
#   'that',
#   'didn',
#   'like',
#   'have',
#   'seen',
#   'complaints',
#   'about',
#   'getting',
#   'good',
#   'portions',
#   'what',
#   'always',
#   'leave',
#   'full',
#   'beyond',
#   'satisfied',
#   'this',
#   'should',
#   'visit',
#   'austin',
#   'without',
#   'stopping',
#   'here',
#   'least',
#   'once'],
#  ['beers',
#   'super',
#   'fast',
#   'service',
#   'with',
#   'tons',
#   'counters',
#   'wicked',
#   'crowded',
#   'place',
#   'have',
#   'deep',
#   'conversation',
#   'great',
#   'spot',
#   'grab',
#   'some',
#   'food',
#   'before',
#   'game'],
#  ['came',
#   'here',
#   'because',
#   'good',
#   'reviews',
#   'ravings',
#   'from',
#   'locals',
#   'plus',
#   'craving',
#   'some',
#   'awesome',
#   'fried',
#   'chicken',
#   'hmmm',
#   'where',
#   'begin',
#   'consider',
#   'myself',
#   'expert',
#   'fried',
#   'chicken',
#   'this',
#   'place',
#   'make',
#   'dance',
#   'chicken',
#   'bland',
#   'didnt',
#   'have',
#   'golden',
#   'color',
#   'awesome',
#   'southern',
#   'fried',
#   'chicken',
#   'that',
#   'have',
#   'missed',
#   'much',
#   'mean',
#   'really',
#   'loves',
#   'light',
#   'sickly',
#   'brown',
#   'chicken',
#   'wings',
#   'that',
#   'wings',
#   'look',
#   'like',
#   'they',
#   'came',
#   'from',
#   'some',
#   'midget',
#   'chickens',
#   'literally',
#   'douse',
#   'these',
#   'wings',
#   'with',
#   'whole',
#   'bottle',
#   'rooster',
#   'just',
#   'down',
#   'then',
#   'ordered',
#   'chicken',
#   'dumplings',
#   'dont',
#   'know',
#   'what',
#   'those',
#   'came',
#   'from',
#   'they',
#   'were',
#   'nasty',
#   'dessert',
#   'hasnt',
#   'come',
#   'based',
#   'spread',
#   'just',
#   'diarrhea',
#   'lord',
#   'help',
#   'dont',
#   'know',
#   'what',
#   'hell',
#   'kind',
#   'people',
#   'like',
#   'this',
#   'kind',
#   'food'],
#  ['shopped',
#   'here',
#   'times',
#   'different',
#   'things',
#   'great',
#   'advice',
#   'other',
#   'shops',
#   'also',
#   'referred',
#   'here',
#   'because',
#   'they',
#   'didn',
#   'have',
#   'what',
#   'needed',
#   'excited',
#   'find',
#   'some',
#   'local',
#   'products',
#   'apparently',
#   'people',
#   'like',
#   'sleep',
#   'because',
#   'much',
#   'matress',
#   'related',
#   'stuff',
#   'made',
#   'here',
#   'colorado',
#   'talked',
#   'employees',
#   'here',
#   'father',
#   'both',
#   'were',
#   'knowledgeable',
#   'about',
#   'their',
#   'products',
#   'concept',
#   'sleep',
#   'they',
#   'seemed',
#   'much',
#   'more',
#   'interested',
#   'making',
#   'sure',
#   'that',
#   'something',
#   'happy',
#   'with',
#   'than',
#   'found',
#   'other',
#   'similar',
#   'shops',
#   'that',
#   'other',
#   'places',
#   'visited',
#   'were',
#   'really',
#   'having',
#   'good',
#   'products',
#   'service',
#   'they',
#   'have',
#   'good',
#   'location',
#   'hours',
#   'experience',
#   'with',
#   'delivery',
#   'picked',
#   'stuff',
#   'bottom',
#   'line',
#   'felt',
#   'their',
#   'shop',
#   'notch',
#   'much',
#   'more',
#   'happy',
#   'give',
#   'them',
#   'than',
#   'mattress',
#   'czar',
#   'super',
#   'chain',
#   'just',
#   'searched',
#   'there',
#   'seem',
#   'four',
#   'shops',
#   'texas',
#   'check',
#   'always',
#   'leave',
#   'sticker',
#   'shocked'],
#  ['only',
#   'server',
#   'luke',
#   'brought',
#   'this',
#   'dinning',
#   'experience',
#   'three',
#   'star',
#   'brisket',
#   'tacos',
#   'were',
#   'tough',
#   'flavorless',
#   'house',
#   'margarita',
#   'sour',
#   'just',
#   'plain',
#   'terrible',
#   'were',
#   'party',
#   'server',
#   'super',
#   'others',
#   'enjoyed',
#   'their',
#   'meals',
#   'maybe',
#   'just',
#   'picked',
#   'wrong',
#   'food',
#   'drink'],
#  ['goes',
#   'this',
#   'real',
#   'quick',
#   'give',
#   'stars',
#   'coming',
#   'here',
#   'always',
#   'means',
#   'forking',
#   'money',
#   'want'],
#  ['unprofessional',
#   'staff',
#   'here',
#   'they',
#   'will',
#   'tell',
#   'anything',
#   'phone',
#   'felt',
#   'like',
#   'lied',
#   'about',
#   'long',
#   'return',
#   'product',
#   'treated',
#   'unfairly',
#   'when',
#   'attempting'],
#  ['were',
#   'hungry',
#   'after',
#   'spending',
#   'hours',
#   'costco',
#   'hotdogs',
#   'pizzas',
#   'were',
#   'palate',
#   'used',
#   'yelp',
#   'find',
#   'nearest',
#   'restaurant',
#   'around',
#   'area',
#   'decided',
#   'thai',
#   'food',
#   'were',
#   'lost',
#   'first',
#   'difficult',
#   'find',
#   'place',
#   'just',
#   'hole',
#   'wall',
#   'enticing',
#   'shopping',
#   'plaza',
#   'costco',
#   'sandy',
#   'blvd',
#   'didn',
#   'know',
#   'what',
#   'order',
#   'stuck',
#   'with',
#   'what',
#   'know',
#   'thai',
#   'noodles',
#   'curry',
#   'since',
#   'there',
#   'just',
#   'ordered',
#   'plate',
#   'drunken',
#   'noodles',
#   'curry',
#   'both',
#   'with',
#   'beef',
#   'course',
#   'also',
#   'thai',
#   'iced',
#   'curry',
#   'came',
#   'smelling',
#   'really',
#   'good',
#   'mouth',
#   'were',
#   'salivating',
#   'rice',
#   'came',
#   'heart',
#   'shape',
#   'which',
#   'niece',
#   'delight',
#   'drunken',
#   'noodles',
#   'were',
#   'sweet',
#   'taste',
#   'still',
#   'good',
#   'nevertheless',
#   'portion',
#   'pretty',
#   'generous',
#   'ended',
#   'packing',
#   'rest',
#   'food',
#   'late',
#   'dinner',
#   'niece',
#   'really',
#   'loved',
#   'thoughtfulness',
#   'heart',
#   'shaped',
#   'rice',
#   'this',
#   'little',
#   'gesture',
#   'definitely',
#   'gets',
#   'coming',
#   'back',
#   'more',
#   'future',
#   'also',
#   'noticed',
#   'extensive',
#   'lunch',
#   'menu',
#   'chicken',
#   'beef',
#   'seafood',
#   'hopefully',
#   'next',
#   'costco',
#   'expedition',
#   'ends',
#   'noon'],
#  ['best',
#   'place',
#   'ever',
#   'here',
#   'breakfast',
#   'lunch',
#   'dinner',
#   'possible',
#   'easy',
#   'walk',
#   'from',
#   'beacon',
#   'hill',
#   'staff',
#   'accommodating',
#   'cheese',
#   'selection',
#   'superb',
#   'only',
#   'downside',
#   'wine'],
#  ['husband',
#   'came',
#   'evening',
#   'food',
#   'unfortunately',
#   'most',
#   'inedible',
#   'hummus',
#   'very',
#   'gritty',
#   'texture',
#   'sooooo',
#   'salty',
#   'falafel',
#   'were',
#   'soggy',
#   'cold',
#   'soaked',
#   'grease',
#   'they',
#   'make',
#   'their',
#   'pita',
#   'bread',
#   'baklava',
#   'rice',
#   'very',
#   'under',
#   'cooked',
#   'hard',
#   'salad',
#   'limp',
#   'swimming',
#   'husband',
#   'however',
#   'enjoy',
#   'kabob',
#   'quite',
#   'over',
#   'cooked',
#   'though',
#   'something',
#   'similar',
#   'jerky',
#   'good',
#   'flavor',
#   'inside',
#   'restaurant',
#   'mess',
#   'oddly',
#   'sticky',
#   'floors',
#   'dishes',
#   'piled',
#   'overall',
#   'were',
#   'quite',
#   'unimpressed',
#   'figure',
#   'high',
#   'ratings',
#   'prolific',
#   'perhaps',
#   'came',
#   'time',
#   'idea',
#   'will',
#   'continue',
#   'giving',
#   'business',
#   'arpeggio',
#   'grill',
#   'whose',
#   'food',
#   'consistent',
#   'better',
#   'quality'],
#  ['think',
#   'food',
#   'here',
#   'great',
#   'have',
#   'eaten',
#   'there',
#   'least',
#   'times',
#   'have',
#   'never',
#   'experience',
#   'food',
#   'indian',
#   'there',
#   'similarities',
#   'more',
#   'refined',
#   'taste',
#   'kinds',
#   'individual',
#   'spices',
#   'flavors',
#   'that',
#   'muddled',
#   'together',
#   'indian',
#   'food',
#   'have',
#   'eaten',
#   'just',
#   'opinion',
#   'course',
#   'maybe',
#   'just',
#   'haven',
#   'that',
#   'good',
#   'indian',
#   'food',
#   'although',
#   'like',
#   'indian',
#   'food'],
#  ['they',
#   'care',
#   'about',
#   'their',
#   'customers',
#   'here',
#   'what',
#   'posted',
#   'their',
#   'faceb',
#   'ordered',
#   'bracelets',
#   'before',
#   'changed',
#   'your',
#   'processing',
#   'time',
#   'from',
#   'days',
#   'when',
#   'finally',
#   'through',
#   'after',
#   'calling',
#   'over',
#   'times',
#   'seriously',
#   'busy',
#   'signal',
#   'asked',
#   'have',
#   'shipping',
#   'expedited',
#   'because',
#   'ship',
#   'order',
#   'family',
#   'along',
#   'with',
#   'other',
#   'gifts',
#   'them',
#   'were',
#   'told',
#   'only',
#   'ship',
#   'ground',
#   'make',
#   'exceptions',
#   'your',
#   'responses',
#   'better',
#   'business',
#   'bureau',
#   'complaints',
#   'only',
#   'actual',
#   'response',
#   'from',
#   'someone',
#   'closer',
#   'christmas',
#   'switched',
#   'then',
#   'overnight',
#   'couldn',
#   'make',
#   'that',
#   'exception',
#   'when',
#   'explained',
#   'situation',
#   'also',
#   'wouldn',
#   'change',
#   'shipping',
#   'address',
#   'could',
#   'send',
#   'them',
#   'directly',
#   'family',
#   'this',
#   'still',
#   'days',
#   'before',
#   'actually',
#   'shipped',
#   'them',
#   'your',
#   'talk',
#   'about',
#   'positivity',
#   'sure',
#   'leave',
#   'customers',
#   'feeling',
#   'negative',
#   'bitter'],
#  ['terrible',
#   'experience',
#   'with',
#   'ztrip',
#   'yellow',
#   'used',
#   'make',
#   'reservation',
#   'night',
#   'before',
#   'boulder',
#   'transit',
#   'center',
#   'catch',
#   'airport',
#   'morning',
#   'notification',
#   'your',
#   'driver',
#   'enroute',
#   'fifteen',
#   'minutes',
#   'after',
#   'should',
#   'have',
#   'arrived',
#   'called',
#   'yellow',
#   'dispatcher',
#   'said',
#   'drivers',
#   'have',
#   'picked',
#   'your',
#   'reservation',
#   'drivers',
#   'decide',
#   'they',
#   'feel',
#   'like',
#   'honoring',
#   'reservation',
#   'missed',
#   'airport',
#   'text',
#   'minutes',
#   'later',
#   'apologize',
#   'your',
#   'driver',
#   'cancel',
#   'please',
#   'booking',
#   'another',
#   'trip',
#   'never',
#   'again'],
#  ['found',
#   'this',
#   'place',
#   'yelp',
#   'always',
#   'looking',
#   'great',
#   'little',
#   'breakfast',
#   'place',
#   'that',
#   'close',
#   'home',
#   'service',
#   'super',
#   'friendly',
#   'decor',
#   'cute',
#   'food',
#   'itself',
#   'pretty',
#   'good',
#   'wouldn',
#   'rave',
#   'about',
#   'solid',
#   'meals',
#   'portions',
#   'were',
#   'generous',
#   'none',
#   'left',
#   'hungry',
#   'bill',
#   'five',
#   'breakfast',
#   'close',
#   'felt',
#   'little',
#   'steep',
#   'considering',
#   'order',
#   'counter',
#   'basically',
#   'good',
#   'diner',
#   'food',
#   'overall',
#   'return',
#   'here',
#   'wouldn',
#   'rush',
#   'back'],
#  ['after',
#   'living',
#   'florida',
#   'months',
#   'finally',
#   'convinced',
#   'family',
#   'vegetarians',
#   'give',
#   'start',
#   'with',
#   'good',
#   'decent',
#   'tasting',
#   'food',
#   'comes',
#   'very',
#   'quick',
#   'although',
#   'there',
#   'were',
#   'only',
#   'groups',
#   'diners',
#   'restaurant',
#   'time',
#   'everything',
#   'covered',
#   'vegetables',
#   'mean',
# ...
#   'worth',
#   'waiting',
#   'line',
#   'long',
#   'only',
#   'hurried',
#   'along',
#   'unfriendly',
#   'staff',
#   'when',
#   'your',
#   'turn',
#   'order',
#   'while',
#   'being',
#   'overwhelmed',
#   'trying',
#   'choose',
#   'something',
#   'they',
#   'even',
#   'have',
#   'coffee',
#   'everyone',
#   'wants',
#   'coffee',
#   'with',
#   'donut',
#   'right',
#   'plus',
#   'cash',
#   'only',
#   'what',
#   'year',
#   'people',
#   'best',
#   'memory',
#   'have',
#   'bronze',
#   'adorned',
#   'that',
#   'showed',
#   'started',
#   'dancing',
#   'street',
#   'monkey',
#   'mask',
#   'only',
#   'grandpa',
#   'join',
#   'lucky',
#   'mean',
#   'would',
#   'probably',
#   'come',
#   'back',
#   'some',
#   'other',
#   'donuts',
#   'since',
#   'live',
#   'miles',
#   'away',
#   'that',
#   'going',
#   'happen',
#   'anytime',
#   'soon'],
#  ['cute',
#   'place',
#   'hang',
#   'nice',
#   'warm',
#   'ambience',
#   'food',
#   'pretty',
#   'good',
#   'reasonably',
#   'priced',
#   'went',
#   'brunch',
#   'weekday',
#   'turned',
#   'awesome',
#   'they',
#   'have',
#   'options',
#   'hubby',
#   'ordered',
#   'duck',
#   'sweet',
#   'potato',
#   'hash',
#   'loved',
#   'generous',
#   'portion',
#   'well',
#   'cooked',
#   'blueberry',
#   'pancakes',
#   'which',
#   'were',
#   'really',
#   'good',
#   'definitely',
#   'recommend',
#   'this',
#   'place'],
#  ['came',
#   'here',
#   'hungry',
#   'bite',
#   'just',
#   'finished',
#   'with',
#   'business',
#   'seminar',
#   'about',
#   'time',
#   'something',
#   'into',
#   'tummies',
#   'great',
#   'location',
#   'just',
#   'right',
#   'main',
#   'street',
#   'lake',
#   'mary',
#   'blvd',
#   'which',
#   'gets',
#   'pretty',
#   'busy',
#   'during',
#   'week',
#   'there',
#   'were',
#   'plenty',
#   'available',
#   'parking',
#   'spaces',
#   'during',
#   'late',
#   'saturday',
#   'afternoon',
#   'restaurant',
#   'empty',
#   'clean',
#   'great',
#   'like',
#   'rest',
#   'panera',
#   'locations',
#   'visited',
#   'great',
#   'customer',
#   'service',
#   'very',
#   'little',
#   'waiting',
#   'time',
#   'food',
#   'ordered',
#   'from',
#   'pick',
#   'menu',
#   'half',
#   'steak',
#   'arugula',
#   'sandwich',
#   'made',
#   'with',
#   'seared',
#   'steak',
#   'arugula',
#   'vine',
#   'ripened',
#   'tomatoes',
#   'pickled',
#   'onions',
#   'garlic',
#   'herb',
#   'cream',
#   'cheese',
#   'spread',
#   'mustard',
#   'horseradish',
#   'sauce',
#   'sour',
#   'dough',
#   'bread',
#   'favorite',
#   'delicious',
#   'clam',
#   'chowder',
#   'okay',
#   'favorite',
#   'will',
#   'satisfy',
#   'appetite',
#   'great',
#   'location',
#   'always',
#   'have',
#   'great',
#   'experiences',
#   'with',
#   'panera',
#   'there',
#   'wasn',
#   'anything',
#   'that',
#   'stood',
#   'from',
#   'rest',
#   'them'],
#  ['going',
#   'honest',
#   'here',
#   'used',
#   'hate',
#   'whip',
#   'food',
#   'always',
#   'seemed',
#   'guess',
#   'that',
#   'always',
#   'just',
#   'picked',
#   'wrong',
#   'time',
#   'when',
#   'just',
#   'busy',
#   'mood',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'blah',
#   'anyways',
#   'hate',
#   'longer',
#   'might',
#   'havana',
#   'rice',
#   'bowl',
#   'dish',
#   'almost',
#   'single',
#   'handedly',
#   'changed',
#   'mind',
#   'california',
#   'benny',
#   'before',
#   'always',
#   'just',
#   'much',
#   'hollandaise',
#   'weird',
#   'chunky',
#   'tomatoes',
#   'bleh',
#   'havana',
#   'rice',
#   'bowl',
#   'with',
#   'added',
#   'avocado',
#   'swack',
#   'hotsauce',
#   'hangover',
#   'brunch',
#   'heaven',
#   'wash',
#   'down',
#   'with',
#   'manmosa',
#   'take',
#   'your',
#   'brunch',
#   'next',
#   'level',
#   'also',
#   'have',
#   'mentioned',
#   'that',
#   'they',
#   'have',
#   'wonderful',
#   'assortment',
#   'beers',
#   'furthermore',
#   'staff',
#   'here',
#   'lovely',
#   'super',
#   'friendly',
#   'attentive',
#   'just',
#   'around',
#   'swell',
#   'folks',
#   'whip',
#   'regular',
#   'rotation',
#   'pleasant',
#   'haunts',
#   'anticipate',
#   'that',
#   'will',
#   'some',
#   'time'],
#  ['food',
#   'service',
#   'were',
#   'great',
#   'came',
#   'after',
#   'lunch',
#   'wait',
#   'ended',
#   'parking',
#   'around',
#   'corner',
#   'what',
#   'else',
#   'expect',
#   'will',
#   'come',
#   'back',
#   'area',
#   'again'],
#  ['really',
#   'surprised',
#   'reviews',
#   'here',
#   'yeah',
#   'walls',
#   'were',
#   'full',
#   'graffiti',
#   'thats',
#   'something',
#   'they',
#   'help',
#   'they',
#   'just',
#   'happen',
#   'next',
#   'university',
#   'with',
#   'bunch',
#   'college',
#   'kids',
#   'seem',
#   'enjoy',
#   'writing',
#   'walls',
#   'food',
#   'amazing',
#   'boyfriend',
#   'said',
#   'best',
#   'quesadilla',
#   'ever',
#   'chicken',
#   'fajita',
#   'great',
#   'chicken',
#   'juicy',
#   'flavorful',
#   'rest',
#   'veggies',
#   'were',
#   'great',
#   'server',
#   'cutest',
#   'quirkiest',
#   'girl',
#   'ever',
#   'very',
#   'attentive',
#   'helpful',
#   'boyfriend',
#   'really',
#   'like',
#   'place',
#   'plan',
#   'back'],
#  ['course',
#   'lunch',
#   'dollars',
#   'with',
#   'people',
#   'started',
#   'with',
#   'duck',
#   'samosas',
#   'which',
#   'thought',
#   'were',
#   'unique',
#   'combination',
#   'they',
#   'were',
#   'okay',
#   'just',
#   'okay',
#   'nothing',
#   'course',
#   'ordered',
#   'sour',
#   'soup',
#   'which',
#   'didn',
#   'particularly',
#   'like',
#   'water',
#   'flavor',
#   'friend',
#   'ordered',
#   'noodle',
#   'watermelon',
#   'salad',
#   'which',
#   'loved',
#   'then',
#   'ordered',
#   'desi',
#   'chili',
#   'chicken',
#   'which',
#   'actually',
#   'liked',
#   'friends',
#   'ordered',
#   'lamb',
#   'dish',
#   'liked',
#   'that',
#   'well',
#   'they',
#   'should',
#   'give',
#   'customers',
#   'option',
#   'ordering',
#   'basmati',
#   'rice',
#   'which',
#   'actually',
#   'prefer',
#   'having',
#   'opposed',
#   'just',
#   'giving',
#   'sticky',
#   'rice',
#   'which',
#   'like',
#   'desert',
#   'vanilla',
#   'cream',
#   'with',
#   'lechee',
#   'actually',
#   'quite',
#   'good',
#   'mistake',
#   'made',
#   'ordering',
#   'pitcher',
#   'sangria',
#   'which',
#   'cost',
#   'dollars',
#   'pathetically',
#   'advise',
#   'them',
#   'stick',
#   'beer',
#   'wine',
#   'order',
#   'sangria',
#   'overall',
#   'bucks',
#   'good',
#   'deal',
#   'newbury',
#   'street',
#   'food',
#   'quite',
#   'flavorful',
#   'pretty',
#   'light',
#   'portion',
#   'sizes',
#   'just',
#   'right',
#   'outdoor',
#   'sitting',
#   'very',
#   'cramped',
#   'waiters',
#   'kept',
#   'dropping',
#   'plates',
#   'luckily',
#   'none',
#   'dropped',
#   'they',
#   'even',
#   'tried',
#   'squeeze',
#   'table',
#   'right',
#   'below',
#   'stairs',
#   'really',
#   'think',
#   'dollar',
#   'course',
#   'deal',
#   'more',
#   'people',
#   'there',
#   'that',
#   'price'],
#  ['dependable',
#   'injun',
#   'food',
#   'they',
#   'have',
#   'great',
#   'staff',
#   'think',
#   'they',
#   'have',
#   'best',
#   'nann',
#   'aint',
#   'picky',
#   'favorites',
#   'sagg',
#   'paneer',
#   'chicken',
#   'tikka',
#   'masala',
#   'order',
#   'about',
#   'times',
#   'month',
#   'take',
#   'dependable'],
#  ['came',
#   'here',
#   'late',
#   'boozy',
#   'lunch',
#   'friday',
#   'staff',
#   'were',
#   'ever',
#   'friendly',
#   'beers',
#   'veggie',
#   'hotdogs',
#   'veggie',
#   'chilli',
#   'cheese',
#   'waffle',
#   'fries',
#   'good',
#   'service',
#   'exemplary',
#   'food',
#   'left',
#   'full',
#   'satisfied',
#   'love',
#   'more',
#   'inventive',
#   'veggie',
#   'vegan',
#   'option',
#   'menu',
#   'though'],
#  ['been',
#   'meaning',
#   'this',
#   'place',
#   'glad',
#   'finally',
#   'amazing',
#   'selection',
#   'baked',
#   'goods',
#   'very',
#   'hard',
#   'choose',
#   'prices',
#   'very',
#   'affordable',
#   'good',
#   'service',
#   'card',
#   'minimum',
#   'either',
#   'which',
#   'great',
#   'considering',
#   'cherry',
#   'danish',
#   'under',
#   'definitely',
#   'going',
#   'back'],
#  ['love',
#   'their',
#   'pizza',
#   'they',
#   'delivered',
#   'extra',
#   'large',
#   'pizza',
#   'place',
#   'business',
#   'employee',
#   'appreciation',
#   'event',
#   'everyone',
#   'raved',
#   'about',
#   'flavors',
#   'crust',
#   'toppings',
#   'hidden',
#   'treasure',
#   'kind',
#   'worth'],
#  ['some',
#   'best',
#   'service',
#   'atlanta',
#   'this',
#   'friday',
#   'servers',
#   'name',
#   'manager',
#   'kitchen',
#   'manager',
#   'gentleman',
#   'with',
#   'terrific',
#   'people',
#   'skills'],
#  ['flower',
#   'factory',
#   'first',
#   'choice',
#   'florists',
#   'book',
#   'wedding',
#   'until',
#   'called',
#   'adjustment',
#   'first',
#   'consultation',
#   'looking',
#   'increase',
#   'spend',
#   'with',
#   'them',
#   'shocked',
#   'rude',
#   'lady',
#   'phone',
#   'didn',
#   'name',
#   'told',
#   'that',
#   'they',
#   'quote',
#   'wanted',
#   'changes',
#   'would',
#   'have',
#   'sign',
#   'contract',
#   'deposit',
#   'first',
#   'could',
#   'possibly',
#   'have',
#   'made',
#   'mind',
#   'when',
#   'minute',
#   'consult',
#   'rough',
#   'costs',
#   'expected',
#   'more',
#   'from',
#   'them',
#   'disappointed',
#   'spoken',
#   'phone',
#   'person',
#   'rude',
#   'short',
#   'with',
#   'didn',
#   'realize',
#   'that',
#   'wanting',
#   'spend',
#   'more',
#   'money',
#   'meant',
#   'treated',
#   'worse',
#   'this',
#   'experience',
#   'totally',
#   'from',
#   'ever',
#   'wanting',
#   'support',
#   'this',
#   'business',
#   'really',
#   'because',
#   'they',
#   'were',
#   'florist',
#   'that',
#   'fiancé',
#   'bought',
#   'first',
#   'bouquet',
#   'flowers',
#   'from',
#   'thought',
#   'would',
#   'sweet',
#   'book',
#   'them',
#   'wedding',
#   'beautiful',
#   'shop',
#   'flowers',
#   'horrible',
#   'service',
#   'experience',
#   'never',
#   'going',
#   'back'],
#  ['love',
#   'this',
#   'place',
#   'after',
#   'waxing',
#   'experience',
#   'came',
#   'here',
#   'with',
#   'uneven',
#   'brows',
#   'nervous',
#   'because',
#   'never',
#   'tried',
#   'threading',
#   'before',
#   'ended',
#   'loving',
#   'experience',
#   'opposed',
#   'waxing',
#   'there',
#   'redness',
#   'deal',
#   'with',
#   'afterwards',
#   'moreover',
#   'with',
#   'help',
#   'ranju',
#   'able',
#   'leave',
#   'with',
#   'nicely',
#   'shaped',
#   'brows',
#   'only',
#   'about',
#   'this',
#   'place',
#   'that',
#   'little',
#   'have',
#   'take',
#   'drive',
#   'there',
#   'worth',
#   'trip',
#   'official',
#   'threading',
#   'convert'],
#  ['sweet',
#   'playground',
#   'drive',
#   'because',
#   'going',
#   'want',
#   'walk',
#   'around',
#   'till',
#   'find'],
#  ['grand',
#   'variety',
#   'flavors',
#   'with',
#   'detailed',
#   'nutritional',
#   'info',
#   'cute',
#   'bright',
#   'store',
#   'great',
#   'hangout',
#   'specially',
#   'after',
#   'movies',
#   'sticker',
#   'door',
#   'shirt',
#   'shoes',
#   'froyo',
#   'sure',
#   'what',
#   'meant',
#   'anyways',
#   'their',
#   'peach',
#   'mango',
#   'flavor',
#   'because',
#   'like',
#   'tart',
#   'froyo',
#   'always',
#   'froyo',
#   'with',
#   'mochi',
#   'rice',
#   'strawberries',
#   'which',
#   'they',
#   'they',
#   'have',
#   'toppings',
#   'available',
#   'much',
#   'fresh',
#   'fruits',
#   'though',
#   'only',
#   'strawberry',
#   'pineapple',
#   'mango',
#   'could',
#   'also',
#   'because',
#   'came',
#   'before',
#   'their',
#   'closing',
#   'time',
#   'wasn',
#   'that',
#   'late',
#   'would',
#   'gotten',
#   'their',
#   'latte',
#   'flavor',
#   'says',
#   'made',
#   'with',
#   'real',
#   'coffee',
#   'worried',
#   'about',
#   'caffeine',
#   'staying',
#   'night',
#   'their',
#   'cheesecake',
#   'flavor',
#   'very',
#   'creamy',
#   'definitely',
#   'tasted',
#   'like',
#   'also',
#   'almond',
#   'biscotti',
#   'which',
#   'made',
#   'with',
#   'real',
#   'almond',
#   'milk',
#   'complaint',
#   'have',
#   'store',
#   'shaped',
#   'there',
#   'enough',
#   'room',
#   'tiny',
#   'isle',
#   'where',
#   'yogurt',
#   'round',
#   'shaped',
#   'cashier',
#   'area',
#   'crams',
#   'everyone',
#   'there',
#   'only',
#   'hold',
#   'person',
#   'time',
#   'wanted',
#   'next',
#   'flavor',
#   'while',
#   'someone',
#   'tastes',
#   'another',
#   'would',
#   'have',
#   'wait',
#   'that',
#   'person',
#   'move',
#   'gotta',
#   'petite',
#   'person',
#   'through',
#   'space',
#   'means',
#   'there',
#   'really',
#   'much',
#   'space',
#   'when',
#   'there',
#   'people',
#   'that',
#   'isle',
#   'waiting',
#   'yogurt',
#   'feels',
#   'like',
#   'rush',
#   'hour',
#   'traffic',
#   'there',
#   'chalkboard',
#   'area',
#   'kids',
#   'draw',
#   'thought',
#   'very',
#   'nice',
#   'menchies',
#   'also',
#   'merchandise',
#   'cute',
#   'buttons',
#   'pencils',
#   'keychains',
#   'shirts',
#   'lastly',
#   'found',
#   'they',
#   'make',
#   'froyo',
#   'cake',
#   'know',
#   'where',
#   'order',
#   'birthday',
#   'cake',
#   'this',
#   'year'],
#  ['this',
#   'restaurant',
#   'small',
#   'cozy',
#   'food',
#   'great',
#   'good',
#   'flavors',
#   'great',
#   'service',
#   'coming',
#   'back'],
#  ['lived',
#   'austin',
#   'long',
#   'time',
#   'long',
#   'enough',
#   'that',
#   'when',
#   'group',
#   'workers',
#   'suggested',
#   'eating',
#   'here',
#   'enormously',
#   'embarrassed',
#   'that',
#   'never',
#   'been',
#   'here',
#   'before',
#   'sitting',
#   'location',
#   'made',
#   'feel',
#   'even',
#   'more',
#   'ambiance',
#   'everything',
#   'love',
#   'about',
#   'austin',
#   'funky',
#   'quirky',
#   'comfy',
#   'cute',
#   'meat',
#   'eater',
#   'second',
#   'favorite',
#   'protein',
#   'tofu',
#   'always',
#   'open',
#   'vegetarian',
#   'food',
#   'really',
#   'impressed',
#   'menu',
#   'know',
#   'many',
#   'group',
#   'folks',
#   'were',
#   'vegetarian',
#   'everyone',
#   'enjoyed',
#   'their',
#   'food',
#   'took',
#   'easy',
#   'route',
#   'grilled',
#   'cheese',
#   'lame',
#   'know',
#   'soooo',
#   'good',
#   'from',
#   'types',
#   'cheese',
#   'sammie',
#   'layer',
#   'basil',
#   'leaves',
#   'flavor',
#   'right',
#   'filling',
#   'choice',
#   'course',
#   'once',
#   'food',
#   'came',
#   'looked',
#   'around',
#   'wish',
#   'selected',
#   'something',
#   'little',
#   'less',
#   'simple',
#   'everything',
#   'looked',
#   'great',
#   'nutella',
#   'latte',
#   'delish',
#   'course',
#   'could',
#   'spread',
#   'nutella',
#   'shoe',
#   'will',
#   'definitely',
#   'back',
#   'this',
#   'great',
#   'option',
#   'veggie',
#   'friends'],
#  ['have',
#   'gone',
#   'years',
#   'dykenight',
#   'second',
#   'saturdays',
#   'while',
#   'they',
#   'biggest',
#   'game',
#   'town',
#   'every',
#   'single',
#   'friends',
#   'same',
#   'complaint',
#   'music',
#   'just',
#   'same',
#   'tired',
#   'techno',
#   'remix',
#   'thumpa',
#   'thumpa',
#   'crap',
#   'again',
#   'again',
#   'music',
#   'outside',
#   'room',
#   'times',
#   'better',
#   'place',
#   'dance',
#   'machine',
#   'sucks',
#   'please',
#   'please',
#   'change',
#   'music',
#   'only',
#   'person',
#   'complained',
#   'please',
#   'play',
#   'some'],
#  ['super',
#   'good',
#   'super',
#   'friendly',
#   'this',
#   'first',
#   'austin',
#   'taco',
#   'truck',
#   'experience',
#   'turned',
#   'really',
#   'good',
#   'husband',
#   'were',
#   'just',
#   'leaving',
#   'yelp',
#   'event',
#   'beef',
#   'taco',
#   'spicy',
#   'chicken',
#   'taco',
#   'husband',
#   'beef',
#   'burrito',
#   'really',
#   'quick',
#   'staff',
#   'really',
#   'friendly',
#   'them',
#   'chatted',
#   'with',
#   'about',
#   'yelp',
#   'event',
#   'said',
#   'that',
#   'been',
#   'trying',
#   'elite',
#   'status',
#   'couldn',
#   'tell',
#   'difference',
#   'between',
#   'chicken',
#   'beef',
#   'them',
#   'bones',
#   'maybe',
#   'that',
#   'chicken',
#   'either',
#   'they',
#   'were',
#   'both',
#   'delish',
#   'husband',
#   'burrito',
#   'spicy',
#   'even',
#   'nixed',
#   'salsa',
#   'hmmm',
#   'tacos',
#   'were',
#   'just',
#   'right',
#   'amount',
#   'spice',
#   'tacos',
#   'burrito',
#   'only',
#   'bucks',
#   'beat',
#   'that'],
#  ['agreement',
#   'with',
#   'ashley',
#   'review',
#   'wanted',
#   'give',
#   'hobos',
#   'longest',
#   'time',
#   'went',
#   'there',
#   'happy',
#   'hour',
#   'decor',
#   'nice',
#   'actually',
#   'rather',
#   'spacious',
#   'inside',
#   'waiter',
#   'nice',
#   'helpful',
#   'beer',
#   'good',
#   'happy',
#   'hour',
#   'food',
#   'comparison',
#   'doesn',
#   'match',
#   'jake',
#   'henry',
#   'really',
#   'hope',
#   'that',
#   'hobos',
#   'would',
#   'revamp',
#   'happy',
#   'hour',
#   'food',
#   'keep',
#   'fries',
#   'tortilla',
#   'salad',
#   'make',
#   'huge',
#   'burger',
#   'hoping',
#   'their',
#   'dinner',
#   'plates',
#   'good',
#   'rachel',
#   'said',
#   'overall',
#   'want',
#   'crowded',
#   'happy',
#   'hour',
#   'place',
#   'hobos',
#   'actually',
#   'decent',
#   'alternative'],
#  ['best',
#   'ride',
#   'park',
#   'mummy',
#   'like',
#   'roller',
#   'coasters',
#   'rides',
#   'that',
#   'this',
#   'that',
#   'ride',
#   'scary',
#   'pregnant',
#   'women',
#   'ride',
#   'opinion',
#   'does',
#   'spin',
#   'will',
#   'hurt',
#   'anything',
#   'months',
#   'pregnant',
#   'hulk',
#   'dragon',
#   'also',
#   'awesome',
#   'suggest',
#   'booking',
#   'come',
#   'march',
#   'however',
#   'ticket',
#   'lines',
#   'retarded',
#   'bought',
#   'tickets',
#   'site',
#   'still',
#   'stand',
#   'line',
#   'hour',
#   'vouchers',
#   'even',
#   'them',
#   'online',
#   'have',
#   'stand',
#   'line',
#   'actual',
#   'ticket',
#   'from',
#   'clerk',
#   'takes',
#   'forever',
#   'need',
#   'least',
#   'days',
#   'through',
#   'universal',
#   'islands',
#   'adventure',
#   'trying',
#   'park',
#   'camper',
#   'turn',
#   'valet']]

# %%
def removeSW(texts_tokens):
    stopWords = set(stopwords.words('english'))
    texts_filtered = []

    for i, val in enumerate(texts_tokens):
        text_filtered = []
        for w in val:
            if w not in stopWords:
                text_filtered.append(w)
        texts_filtered.append(text_filtered)
        
    return texts_filtered

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Out[28]: True

# %%
stopwords.words('english')
# Out:
# Out[30]: ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
texts_filtered = removeSW(texts_tokens)

# %%
label=[]
for sentence in texts_filtered:
    for tokens in sentence:
        lp=[]
        ln=[]
        if tokens in positive_list:
            lp.append(tokens)
        if tokens in negative_list:
            ln.append(tokens)
    if len(lp)>len(ln):
        label.append("P")
    else:
        label.append("N")

# %%
final_label=label

# %%
type(texts_filtered)
# Out:
# Out[59]: list

# %%
dataframe = spark.createDataFrame(zip(texts,label), ["text","label"])

# %%
dataframe.show(10,truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |label|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# |Ever wanted too just take a bite out of a fully grown hogs gut  That is what the five guys experience is about for me  The burgers are unreal and extremely good  Also they are generous with the fries that overflow into the bag  but the amount of fries used to be better  But the one thing that is distracting from the experience is all of the peanut corpses littered around the place  It is nut genocide  Makes me feel very uncomfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |N    |
# |Dry aged bone in ribeye  Best steak I ve ever eaten   The corn pudding was also delicious and exceeded expectations  We loved the lobster Napoleon  but I wouldn t order it again unless we were splurging  The steak is  so delicious and filling that you won t need an appetizer  The truffle mashed potatoes were delicious  but they were also what we expected from this quality of restaurant  The mac and cheese was good  but not our favorite kind  It tasted like it was trying too hard   I personally would pass on the cheesecake  It was good  but not spectacular   The point of this story is that the steak was so good  the waiter could ve slapped my mother in front of me  and I still would ve given a   star review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |N    |
# |I lived in Boston for years before I was tipped off to this location  The food court is an asian food lover s dream come true  From dim sum to stir fry  and from Pho to indian food  this place has it all  Oh  and lolicup provides a tasty drink dessert option   Dim sum here is especially good  but you can get great Udon stir frys as well  Cash only  but there is an ATM on site                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |N    |
# |Some good things about Alibi  comfortable areas to sit and talk with a small or large group of people  the kind of lighting that makes people look prettier  perfectly pleasant and not too loud music  plenty of people but not at all crowded  decent drinks  close to the red line at Charles MGH  cheap and quick and friendly valet parking  only     if you get your ticket validated at Alibi or Clink    a great deal in a neighborhood where street parking is slim pickings especially when there s a Celtics game or some other event at the Garden    Some annoying things  long lines outside on freezing cold Friday nights are one thing if a place really is at capacity  but doing it for effect is just obnoxious  after waiting for at least twenty minutes to get in  my friends and I realized that holding back the floods had not been strictly necessary  they easily could have let in the whole line  maybe    people  without making the place uncomfortably full  Then four of our friends who got there after we did  they arrived around ten  waited for over an hour  including about    minutes  at the very front of the line   and finally ended up leaving to avoid frostbite  Maybe they weren t wearing enough makeup or something  but this one bouncer was really rudely power trippy about the whole thing  In general the staff members  other than the valets  were not great  for example our clueless cocktail waitress about whom one of my friends speculated charitably that it was probably her first day  She would come back to our table after ten minutes to point at someone and say    Are  you  the one who ordered the pinot noir   Also  given that a martini glass with an olive laden toothpick sticking out of it is one of the most iconic images in America I was pretty unimpressed that she brought over my dirty martini with no olives in it and apparently  didn t know that martinis are supposed to come with olives   The jailhouse themed decor was kind of cool in a novelty way  although I would have preferred to sit by a mugshot like Michael Jagger or Francis Sinatra rather than having to stare at Paris Hilton s giant sultry gaze  And I can imagine it might be a decent  if expensive  after work hangout if I worked in Boston  especially at MGH  which is right next door  But given that I do not I probably won t be back |N    |
# |Great place to grab a burger on the fly  Fast service and friendly staff  Seating is available inside  All food is made to order  so patience is a virtue  Worth the wait                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |N    |
# |It s like the Walmart of sports merchandise  The prices aren t that great  it s out in the boonies  it s crowded  and Nike gear isn t that great  Some people obviously like it  but it was not for me                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |P    |
# |The food was incredible  The bar tender was very personable  We will definitely be going back there for brunch  The way they incorporate the marvel theme into the restaurant and food is unlike anything I have ever seen  I had the terminator sandwich and my wife had the storm quesadilla with their Bloody Mary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |N    |
# |Haven t been so happy with a restaurant for a while  We had steak sandwiches  two steaks and chicken breast and it all have been AMAZING  We have a diary problem and they made everything from scratch for us  Staff is very nice and truly cared about us  Zero complains  Thank you                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |P    |
# |These guys helped me out with my Yakima rack and had everything I needed in stock   Matt was helpful and gave me a     discount for being nice   Plus I had a coupon                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |N    |
# |great service and wonderful warm ambiance   Food was very good  quick and fresh                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |P    |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+
# only showing top 10 rows

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(texts).toarray()

# %%
df10=dataframe.toPandas()

# %%
y=df10.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# Out[104]: SVC(kernel='linear', random_state=0)

# %%
import numpy as np
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['P' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'P']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['P' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'P']
#  ['N' 'P']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'P']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['P' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'N']
#  ['P' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['P' 'P']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']
#  ['N' 'N']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[70 16]
#  [ 9  5]]
# Out[106]: 0.75

# %%
new_review = 'It s like the Walmart of sports merchandise  The prices aren t that great  it s out in the boonies  it s crowded  and Nike gear isn t that great  Some people obviously like it  but it was not for me '
new_review = re.sub('[^a-zA-Z]', ' ', new_review)
new_review = new_review.lower()
new_review = new_review.split()
ps = PorterStemmer()
all_stopwords = stopwords.words('english')
all_stopwords.remove('not')
new_review = [ps.stem(word) for word in new_review if not word in set(all_stopwords)]
new_review = ' '.join(new_review)
new_corpus = [new_review]
new_X_test = cv.transform(new_corpus).toarray()
new_y_pred = classifier.predict(new_X_test)
print(new_y_pred)
# Out:
# ['N']

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB(alpha=0.8)
mnb.fit(X_train,y_train)
# Out:
# Out[113]: MultinomialNB(alpha=0.8)

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB(alpha=0.5)
bnb.fit(X_train,y_train)
y_pred_bnb=mnb.predict(X_test)

# %%
y_pred_bnb
# Out:
# Out[115]: array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'P', 'N', 'P',
#        'N', 'N', 'N', 'P', 'N', 'P', 'N', 'P', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'P', 'N', 'N', 'N', 'P',
#        'N', 'P', 'N', 'N', 'P', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'P',
#        'N', 'N', 'P', 'N', 'N', 'N', 'N', 'N', 'N'], dtype='<U1')

# %%
accuracy_score(y_test, y_pred_bnb)
# Out:
# Out[117]: 0.79

# %%
dataframe.show(10)
# Out:
# +--------------------+-----+
# |                text|label|
# +--------------------+-----+
# |Ever wanted too j...|    N|
# |Dry aged bone in ...|    N|
# |I lived in Boston...|    N|
# |Some good things ...|    N|
# |Great place to gr...|    N|
# |It s like the Wal...|    P|
# |The food was incr...|    N|
# |Haven t been so h...|    P|
# |These guys helped...|    N|
# |great service and...|    P|
# +--------------------+-----+
# only showing top 10 rows

# %%
df11=review_df.filter(review_df.label=="0")

# %%
df11.show(5)
# Out:
# +--------------------+--------------------+-----+
# |           review_id|                text|label|
# +--------------------+--------------------+-----+
# |Lis1PdpSAKYO2Xphi...|It s like the Wal...|    0|
# |HtlSBk4RQAVPqfW7Z...|Well this place h...|    0|
# |rE4fSpd05jpGMbe4S...|I went to this pl...|    0|
# |xLRe59g6MnWxXaJny...|Ordered a fish sa...|    0|
# |xmaEZy2Add1VpUnF1...|The fact they got...|    0|
# +--------------------+--------------------+-----+
# only showing top 5 rows

# %%
review_df.show(5)
# Out:
# +--------------------+--------------------+-----+
# |           review_id|                text|label|
# +--------------------+--------------------+-----+
# |lyjloY7uVRsaOZObr...|Ever wanted too j...|    1|
# |GfPzojSq1cin_fOdf...|Dry aged bone in ...|    1|
# |lFphcMI6ZN2uFA8wg...|I lived in Boston...|    1|
# |oQDDv49nI55lHzsI3...|Some good things ...|    1|
# |78ZDs404elxc0f1i-...|Great place to gr...|    1|
# +--------------------+--------------------+-----+
# only showing top 5 rows

# %%
dataframe.show(10)
# Out:
# +--------------------+-----+
# |                text|label|
# +--------------------+-----+
# |Ever wanted too j...|    N|
# |Dry aged bone in ...|    N|
# |I lived in Boston...|    N|
# |Some good things ...|    N|
# |Great place to gr...|    N|
# |It s like the Wal...|    P|
# |The food was incr...|    N|
# |Haven t been so h...|    P|
# |These guys helped...|    N|
# |great service and...|    P|
# +--------------------+-----+
# only showing top 10 rows

# %%
df.withColumn("bonus_percent").show()
